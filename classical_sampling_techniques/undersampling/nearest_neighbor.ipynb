# %% [markdown]
# # Imports

# %%
from imblearn.under_sampling import CondensedNearestNeighbour
import numpy as np
import os
import pandas as pd
import random
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.utils import shuffle
from tqdm import tqdm

# %% [markdown]
# # Loading

# %%
DATASET_DIRECTORY = '../../dataset/'  # If your dataset is within your python project directory, change this to the relative path to your dataset
csv_filepaths = [filename for filename in os.listdir(DATASET_DIRECTORY) if filename.endswith('.csv')]

print(csv_filepaths)

# If there are more than X CSV files, randomly select X files from the list
sample_size = 5

if len(csv_filepaths) > sample_size:
    csv_filepaths = random.sample(csv_filepaths, sample_size)
    print(csv_filepaths)

csv_filepaths.sort()

# list of csv files used
data_sets = csv_filepaths

num_cols = [
    'flow_duration', 'Header_Length', 'Duration', 'Rate', 'Srate', 'ack_count', 'syn_count',
    'fin_count', 'urg_count', 'rst_count', 'Tot sum', 'Min', 'Max', 'AVG', 'Std', 'Tot size', 
    'IAT', 'Number', 'Magnitue', 'Radius', 'Covariance', 'Variance', 'Weight'
]
cat_cols = [
    'Protocol Type', 'Drate', 'fin_flag_number', 'syn_flag_number', 'rst_flag_number',
    'psh_flag_number', 'ack_flag_number', 'ece_flag_number', 'cwr_flag_number', 'HTTP', 'HTTPS', 
    'DNS', 'Telnet', 'SMTP', 'SSH', 'IRC', 'TCP', 'UDP', 'DHCP', 'ARP', 'ICMP', 'IPv', 'LLC'
]

full_data = pd.DataFrame()
for data_set in data_sets:
    print(f"data set {data_set} out of {len(data_sets)} \n")
    data_path = os.path.join(DATASET_DIRECTORY, data_set)
    df = pd.read_csv(data_path)
    full_data = pd.concat([full_data, df])

# prints an instance of each class
print("Before encoding:")
unique_labels = full_data['label'].unique()
for label in unique_labels:
    print(f"First instance of {label}:")
    print(full_data[full_data['label'] == label].iloc[0])

# Shuffle data
full_data = shuffle(full_data, random_state=1)

# prove if the data is loaded properly
print("Real data:")
print(full_data[:2])
print(full_data.shape)

# Assuming 'label' is the column name for the labels in the DataFrame `synth_data`
unique_labels = full_data['label'].nunique()

# Print the number of unique labels
print(f"There are {unique_labels} unique labels in the dataset.")

class_counts = full_data['label'].value_counts()
print(class_counts)

# Display the first few entries to verify the changes
full_data.describe()
# Out:
# ['part-00000-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00001-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00002-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00003-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00005-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00007-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00008-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00009-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00010-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00011-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00012-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00013-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00014-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00015-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00016-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00017-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00018-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00019-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00020-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00021-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00022-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00023-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00024-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00025-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00026-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00027-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00028-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00029-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00030-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00031-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00032-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00033-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00034-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00035-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00036-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00037-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00038-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00039-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00040-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00041-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00042-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00043-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00044-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00045-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00046-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00047-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00048-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00049-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00050-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00051-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00052-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00053-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00054-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00055-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00056-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00057-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00058-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00059-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00060-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00061-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00062-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00063-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00064-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00065-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00066-363d1ba3-8ab5-4f96-bc25-4d5 ...
# ['part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00113-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00100-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv', 'part-00121-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv']
# data set part-00004-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv out of 5
#
# data set part-00006-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv out of 5
#
# data set part-00100-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv out of 5
#
# data set part-00113-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv out of 5
#
# data set part-00121-363d1ba3-8ab5-4f96-bc25-4d5862db7cb9-c000.csv out of 5
#
# Before encoding:
# First instance of Mirai-udpplain:
# flow_duration             0.662395
# Header_Length            410946.12
# Protocol Type                 17.0
# Duration                      64.0
# Rate                   1114.559417
# Srate                  1114.559417
# Drate                          0.0
# fin_flag_number                0.0
# syn_flag_number                0.0
# rst_flag_number                0.0
# psh_flag_number                0.0
# ack_flag_number                0.0
# ece_flag_number                0.0
# cwr_flag_number                0.0
# ack_count                      0.0
# syn_count                      0.0
# fin_count                      0.0
# urg_count                      0.0
# rst_count                      0.0
# HTTP                           0.0
# HTTPS                          0.0
# DNS                            0.0
# Telnet                         0.0
# SMTP                           0.0
# SSH                            0.0
# IRC                            0.0
# TCP                            0.0
# UDP                            1.0
# DHCP                           0.0
# ARP                            0.0
# ICMP                           0.0
# IPv                            1.0
# LLC                            1.0
# Tot sum                     5817.0
# Min                          554.0
# Max                          554.0
# AVG                          554.0
# Std                            0.0
# Tot size                     554.0
# IAT                83767545.135987
# Number                         9.5
# Magnitue                 33.286634
# Radius                         0.0
# Covariance                     0.0
# Variance                       0.0
# Weight                      141.55
# label               Mirai-udpplain
# Name: 0, dtype: object
# First instance of DDoS-PSHACK_Flood:
# flow_duration                    0.0
# Header_Length                   54.0
# Protocol Type                    6.0
# Duration                       65.91
# Rate                      230.285448
# Srate                     230.285448
# Drate                            0.0
# fin_flag_number                  0.0
# syn_flag_number                  0.0
# rst_flag_number                  0.0
# psh_flag_number                  1.0
# ack_flag_number                  1.0
# ece_flag_number                  0.0
# cwr_flag_number                  0.0
# ack_count                        0.0
# syn_count                        0.0
# fin_count                       0.01
# urg_count                       0.99
# rst_count                        1.0
# HTTP                             0.0
# HTTPS                            0.0
# DNS                              0.0
# Telnet                           0.0
# SMTP                             0.0
# SSH                              0.0
# IRC                              0.0
# TCP                              1.0
# UDP                              0.0
# DHCP                             0.0
# ARP                              0.0
# ICMP                             0.0
# IPv                              1.0
# LLC                              1.0
# Tot sum                        567.0
# Min                             54.0
# Max                             54.0
# AVG                             54.0
# Std                              0.0
# Tot size                        54.0
# IAT                  83314666.996931
# Number                           9.5
# Magnitue                   10.392305
# Radius                           0.0
# Covariance                       0.0
# Variance                         0.0
# Weight                        141.55
# label              DDoS-PSHACK_Flood
# Name: 1, dtype: object
# First instance of DDoS-ICMP_Flood:
# flow_duration                  0.0
# Header_Length                  0.0
# Protocol Type                  1.0
# Duration                      64.0
# Rate                      7.949886
# Srate                     7.949886
# Drate                          0.0
# fin_flag_number                0.0
# syn_flag_number                0.0
# rst_flag_number                0.0
# psh_flag_number                0.0
# ack_flag_number                0.0
# ece_flag_number                0.0
# cwr_flag_number                0.0
# ack_count                      0.0
# syn_count                      0.0
# fin_count                      0.0
# urg_count                      0.0
# rst_count                      0.0
# HTTP                           0.0
# HTTPS                          0.0
# DNS                            0.0
# Telnet                         0.0
# SMTP                           0.0
# SSH                            0.0
# IRC                            0.0
# TCP                            0.0
# UDP                            0.0
# DHCP                           0.0
# ARP                            0.0
# ICMP                           1.0
# IPv                            1.0
# LLC                            1.0
# Tot sum                      441.0
# Min                           42.0
# Max                           42.0
# AVG                           42.0
# Std                            0.0
# Tot size                      42.0
# IAT                83128684.350801
# Number                         9.5
# Magnitue                  9.165151
# Radius                         0.0
# Covariance                     0.0
# Variance                       0.0
# Weight                      141.55
# label              DDoS-ICMP_Flood
# Name: 2, dtype: object
# First instance of DDoS-RSTFINFlood:
# flow_duration              0.013891
# Header_Length                 68.56
# Protocol Type                  6.22
# Duration                       64.0
# Rate                       2.693528
# Srate                      2.693528
# Drate                           0.0
# fin_flag_number                 1.0
# syn_flag_number                 0.0
# rst_flag_number                 1.0
# psh_flag_number                 0.0
# ack_flag_number                 0.0
# ece_flag_number                 0.0
# cwr_flag_number                 0.0
# ack_count                      0.98
# syn_count                       0.0
# fin_count                      0.98
# urg_count                       0.0
# rst_count                       0.0
# HTTP                            0.0
# HTTPS                           0.0
# DNS                             0.0
# Telnet                          0.0
# SMTP                            0.0
# SSH                             0.0
# IRC                             0.0
# TCP                             1.0
# UDP                             0.0
# DHCP                            0.0
# ARP                             0.0
# ICMP                            0.0
# IPv                             1.0
# LLC                             1.0
# Tot sum                      612.72
# Min                            54.0
# Max                           99.72
# AVG                       59.234057
# Std                       13.754549
# Tot size                      56.64
# IAT                  83344207.23873
# Number                          9.5
# Magnitue                  10.832015
# Radius                    19.471851
# Covariance              1046.392845
# Variance                       0.27
# Weight                       141.55
# label              DDoS-RSTFINFlood
# Name: 3, dtype: object
# First instance of Mirai-greip_flood:
# flow_duration                    0.0
# Header_Length                    0.0
# Protocol Type                   47.0
# Duration                        64.0
# Rate                       43.098954
# Srate                      43.098954
# Drate                            0.0
# fin_flag_number                  0.0
# syn_flag_number                  0.0
# rst_flag_number                  0.0
# psh_flag_number                  0.0
# ack_flag_number                  0.0
# ece_flag_number                  0.0
# cwr_flag_number                  0.0
# ack_count                        0.0
# syn_count                        0.0
# fin_count                        0.0
# urg_count                        0.0
# rst_count                        0.0
# HTTP                             0.0
# HTTPS                            0.0
# DNS                              0.0
# Telnet                           0.0
# SMTP                             0.0
# SSH                              0.0
# IRC                              0.0
# TCP                              0.0
# UDP                              0.0
# DHCP                             0.0
# ARP                              0.0
# ICMP                             0.0
# IPv                              1.0
# LLC                              1.0
# Tot sum                       6069.0
# Min                            578.0
# Max                            578.0
# AVG                            578.0
# Std                              0.0
# Tot size                       578.0
# IAT                    83647270.4103
# Number                           9.5
# Magnitue                        34.0
# Radius                           0.0
# Covariance                       0.0
# Variance                         0.0
# Weight                        141.55
# label              Mirai-greip_flood
# Name: 4, dtype: object
# First instance of DDoS-UDP_Flood:
# flow_duration            0.512294
# Header_Length             29716.0
# Protocol Type                17.0
# Duration                     64.0
# Rate                  2443.929789
# Srate                 2443.929789
# Drate                         0.0
# fin_flag_number               0.0
# syn_flag_number               0.0
# rst_flag_number               0.0
# psh_flag_number               0.0
# ack_flag_number               0.0
# ece_flag_number               0.0
# cwr_flag_number               0.0
# ack_count                     0.0
# syn_count                     0.0
# fin_count                     0.0
# urg_count                     0.0
# rst_count                     0.0
# HTTP                          0.0
# HTTPS                         0.0
# DNS                           0.0
# Telnet                        0.0
# SMTP                          0.0
# SSH                           0.0
# IRC                           0.0
# TCP                           0.0
# UDP                           1.0
# DHCP                          0.0
# ARP                           0.0
# ICMP                          0.0
# IPv                           1.0
# LLC                           1.0
# Tot sum                     525.0
# Min                          50.0
# Max                          50.0
# AVG                          50.0
# Std                           0.0
# Tot size                     50.0
# IAT                 83098374.4554
# Number                        9.5
# Magnitue                     10.0
# Radius                        0.0
# Covariance                    0.0
# Variance                      0.0
# Weight                     141.55
# label              DDoS-UDP_Flood
# Name: 8, dtype: object
# First instance of DoS-UDP_Flood:
# flow_duration             0.082513
# Header_Length             43020.92
# Protocol Type                16.89
# Duration                      64.0
# Rate                  10674.267561
# Srate                 10674.267561
# Drate                          0.0
# fin_flag_number                0.0
# syn_flag_number                0.0
# rst_flag_number                0.0
# psh_flag_number                0.0
# ack_flag_number                0.0
# ece_flag_number                0.0
# cwr_flag_number                0.0
# ack_count                      0.0
# syn_count                     0.02
# fin_count                      0.0
# urg_count                     0.01
# rst_count                     0.04
# HTTP                           0.0
# HTTPS                          0.0
# DNS                            0.0
# Telnet                         0.0
# SMTP                           0.0
# SSH                            0.0
# IRC                            0.0
# TCP                            0.0
# UDP                            1.0
# DHCP                           0.0
# ARP                            0.0
# ICMP                           0.0
# IPv                            1.0
# LLC                            1.0
# Tot sum                     526.28
# Min                           50.0
# Max                          51.28
# AVG                      50.079125
# Std                       0.307378
# Tot size                     50.16
# IAT                83016679.193292
# Number                         9.5
# Magnitue                 10.007915
# Radius                    0.435909
# Covariance                1.192202
# Variance                      0.08
# Weight                      141.55
# label                DoS-UDP_Flood
# Name: 9, dtype: object
# First instance of DDoS-TCP_Flood:
# flow_duration                  0.0
# Header_Length                 54.0
# Protocol Type                  6.0
# Duration                      64.0
# Rate                     17.667369
# Srate                    17.667369
# Drate                          0.0
# fin_flag_number                0.0
# syn_flag_number                0.0
# rst_flag_number                0.0
# psh_flag_number                0.0
# ack_flag_number                0.0
# ece_flag_number                0.0
# cwr_flag_number                0.0
# ack_count                      0.0
# syn_count                      0.0
# fin_count                      0.0
# urg_count                      0.0
# rst_count                      0.0
# HTTP                           0.0
# HTTPS                          0.0
# DNS                            0.0
# Telnet                         0.0
# SMTP                           0.0
# SSH                            0.0
# IRC                            0.0
# TCP                            1.0
# UDP                            0.0
# DHCP                           0.0
# ARP                            0.0
# ICMP                           0.0
# IPv                            1.0
# LLC                            1.0
# Tot sum                      567.0
# Min                           54.0
# Max                           54.0
# AVG                           54.0
# Std                            0.0
# Tot size                      54.0
# IAT                83034010.872536
# Number                         9.5
# Magnitue                 10.392305
# Radius                         0.0
# Covariance                     0.0
# Variance                       0.0
# Weight                      141.55
# label               DDoS-TCP_Flood
# Name: 12, dtype: object
# First instance of DDoS-UDP_Fragmentation:
# flow_duration                    0.218064
# Header_Length                   184953.84
# Protocol Type                       16.83
# Duration                             63.1
# Rate                           561.283103
# Srate                          561.283103
# Drate                                 0.0
# fin_flag_number                       0.0
# syn_flag_number                       0.0
# rst_flag_number                       0.0
# psh_flag_number                       0.0
# ack_flag_number                       0.0
# ece_flag_number                       0.0
# cwr_flag_number                       0.0
# ack_count                             0.0
# syn_count                             0.0
# fin_count                             0.0
# urg_count                             0.0
# rst_count                             0.0
# HTTP                                  0.0
# HTTPS                                 0.0
# DNS                                   0.0
# Telnet                                0.0
# SMTP                                  0.0
# SSH                                   0.0
# IRC                                   0.0
# TCP                                   0.0
# UDP                                   0.0
# DHCP                                  0.0
# ARP                                   0.0
# ICMP                                  0.0
# IPv                                   1.0
# LLC                                   1.0
# Tot sum                           9337.94
# Min                                276.54
# Max                                1456.4
# AVG                            863.126039
# Std                            547.382255
# Tot size                            906.5
# IAT                       83370256.029522
# Number                                9.5
# Magnitue                        41.315488
# Radius                         774.073274
# Covariance                  317537.097101
# Variance                             0.95
# Weight                             141.55
# label              DDoS-UDP_Fragmentation
# Name: 13, dtype: object
# First instance of DDoS-SYN_Flood:
# flow_duration                  0.0
# Header_Length                 54.0
# Protocol Type                  6.0
# Duration                      64.0
# Rate                     70.781809
# Srate                    70.781809
# Drate                          0.0
# fin_flag_number                0.0
# syn_flag_number                1.0
# rst_flag_number                0.0
# psh_flag_number                0.0
# ack_flag_number                0.0
# ece_flag_number                0.0
# cwr_flag_number                0.0
# ack_count                      0.0
# syn_count                      1.0
# fin_count                      0.0
# urg_count                      0.0
# rst_count                      0.0
# HTTP                           0.0
# HTTPS                          0.0
# DNS                            0.0
# Telnet                         0.0
# SMTP                           0.0
# SSH                            0.0
# IRC                            0.0
# TCP                            1.0
# UDP                            0.0
# DHCP                           0.0
# ARP                            0.0
# ICMP                           0.0
# IPv                            1.0
# LLC                            1.0
# Tot sum                      567.0
# Min                           54.0
# Max                           54.0
# AVG                           54.0
# Std                            0.0
# Tot size                      54.0
# IAT                83090109.196192
# Number                         9.5
# Magnitue                 10.392305
# Radius                         0.0
# Covariance                     0.0
# Variance                       0.0
# Weight                      141.55
# label               DDoS-SYN_Flood
# Name: 14, dtype: object
# First instance of BenignTraffic:
# flow_duration            112.023041
# Header_Length              251309.9
# Protocol Type                  13.3
# Duration                       76.8
# Rate                      39.807156
# Srate                     39.807156
# Drate                           0.0
# fin_flag_number                 0.0
# syn_flag_number                 0.0
# rst_flag_number                 0.0
# psh_flag_number                 0.0
# ack_flag_number                 0.0
# ece_flag_number                 0.0
# cwr_flag_number                 0.0
# ack_count                       0.0
# syn_count                       0.0
# fin_count                       0.0
# urg_count                      72.6
# rst_count                     150.7
# HTTP                            0.0
# HTTPS                           0.0
# DNS                             0.0
# Telnet                          0.0
# SMTP                            0.0
# SSH                             0.0
# IRC                             0.0
# TCP                             0.0
# UDP                             1.0
# DHCP                            0.0
# ARP                             0.0
# ICMP                            0.0
# IPv                             1.0
# LLC                             1.0
# Tot sum                      1211.4
# Min                            50.0
# Max                           214.0
# AVG                       78.712793
# Std                        54.26655
# Tot size                       64.8
# IAT                166518834.694727
# Number                         13.5
# Magnitue                   12.55237
# Radius                    76.898602
# Covariance               2967.84935
# Variance                        1.0
# Weight                        244.6
# label                 BenignTraffic
# Name: 18, dtype: object
# First instance of DoS-SYN_Flood:
# flow_duration             0.093531
# Header_Length                 62.1
# Protocol Type                  6.0
# Duration                      64.0
# Rate                        3.2357
# Srate                       3.2357
# Drate                          0.0
# fin_flag_number                0.0
# syn_flag_number                1.0
# rst_flag_number                0.0
# psh_flag_number                0.0
# ack_flag_number                0.0
# ece_flag_number                0.0
# cwr_flag_number                0.0
# ack_count                      0.0
# syn_count                      1.0
# fin_count                     0.15
# urg_count                      0.0
# rst_count                      0.0
# HTTP                           0.0
# HTTPS                          0.0
# DNS                            0.0
# Telnet                         0.0
# SMTP                           0.0
# SSH                            0.0
# IRC                            0.0
# TCP                            1.0
# UDP                            0.0
# DHCP                           0.0
# ARP                            0.0
# ICMP                           0.0
# IPv                            1.0
# LLC                            1.0
# Tot sum                      567.0
# Min                           54.0
# Max                           54.0
# AVG                           54.0
# Std                            0.0
# Tot size                      54.0
# IAT                82985380.906304
# Number                         9.5
# Magnitue                 10.392305
# Radius                         0.0
# Covariance                     0.0
# Variance                       0.0
# Weight                      141.55
# label                DoS-SYN_Flood
# Name: 19, dtype: object
# First instance of DDoS-ACK_Fragmentation:
# flow_duration                         0.0
# Header_Length                      741.86
# Protocol Type                         5.9
# Duration                            65.08
# Rate                                  0.0
# Srate                                 0.0
# Drate                                 0.0
# fin_flag_number                       0.0
# syn_flag_number                       0.0
# rst_flag_number                       0.0
# psh_flag_number                       0.0
# ack_flag_number                       0.0
# ece_flag_number                       0.0
# cwr_flag_number                       0.0
# ack_count                             0.0
# syn_count                             0.0
# fin_count                             0.0
# urg_count                             0.0
# rst_count                            0.49
# HTTP                                  0.0
# HTTPS                                 0.0
# DNS                                   0.0
# Telnet                                0.0
# SMTP                                  0.0
# SSH                                   0.0
# IRC                                   0.0
# TCP                                   0.0
# UDP                                   0.0
# DHCP                                  0.0
# ARP                                   0.0
# ICMP                                  0.0
# IPv                                   1.0
# LLC                                   1.0
# Tot sum                           9705.48
# Min                                349.88
# Max                                1479.8
# AVG                            921.912478
# Std                            541.562651
# Tot size                           927.08
# IAT                       83339818.876102
# Number                                9.5
# Magnitue                        42.788257
# Radius                         765.891631
# Covariance                  308849.198499
# Variance                             0.95
# Weight                             141.55
# label              DDoS-ACK_Fragmentation
# Name: 23, dtype: object
# First instance of MITM-ArpSpoofing:
# flow_duration             35.426525
# Header_Length              468408.0
# Protocol Type                  13.7
# Duration                      166.0
# Rate                      55.912251
# Srate                     55.912251
# Drate                           0.0
# fin_flag_number                 0.0
# syn_flag_number                 0.0
# rst_flag_number                 0.0
# psh_flag_number                 0.0
# ack_flag_number                 0.0
# ece_flag_number                 0.0
# cwr_flag_number                 0.0
# ack_count                       0.0
# syn_count                       0.0
# fin_count                       0.0
# urg_count                       4.4
# rst_count                       8.4
# HTTP                            0.0
# HTTPS                           0.0
# DNS                             0.0
# Telnet                          0.0
# SMTP                            0.0
# SSH                             0.0
# IRC                             0.0
# TCP                             0.0
# UDP                             1.0
# DHCP                            0.0
# ARP                             0.0
# ICMP                            0.0
# IPv                             1.0
# LLC                             1.0
# Tot sum                      2643.8
# Min                            56.4
# Max                           913.0
# AVG                      371.388929
# Std                      335.766478
# Tot size                      533.5
# IAT                        0.017841
# Number                          5.5
# Magnitue                   25.47529
# Radius                   474.845506
# Covariance            167476.789866
# Variance                        0.9
# Weight                         38.5
# label              MITM-ArpSpoofing
# Name: 27, dtype: object
# First instance of DDoS-SynonymousIP_Flood:
# flow_duration                     1.828472
# Header_Length                        108.0
# Protocol Type                          6.0
# Duration                              64.0
# Rate                              1.100339
# Srate                             1.100339
# Drate                                  0.0
# fin_flag_number                        0.0
# syn_flag_number                        1.0
# rst_flag_number                        0.0
# psh_flag_number                        0.0
# ack_flag_number                        0.0
# ece_flag_number                        0.0
# cwr_flag_number                        0.0
# ack_count                              0.0
# syn_count                              2.0
# fin_count                              0.0
# urg_count                              0.0
# rst_count                              0.0
# HTTP                                   0.0
# HTTPS                                  0.0
# DNS                                    0.0
# Telnet                                 0.0
# SMTP                                   0.0
# SSH                                    0.0
# IRC                                    0.0
# TCP                                    1.0
# UDP                                    0.0
# DHCP                                   0.0
# ARP                                    0.0
# ICMP                                   0.0
# IPv                                    1.0
# LLC                                    1.0
# Tot sum                              567.0
# Min                                   54.0
# Max                                   54.0
# AVG                                   54.0
# Std                                    0.0
# Tot size                              54.0
# IAT                        83361430.367211
# Number                                 9.5
# Magnitue                         10.392305
# Radius                                 0.0
# Covariance                             0.0
# Variance                               0.0
# Weight                              141.55
# label              DDoS-SynonymousIP_Flood
# Name: 28, dtype: object
# First instance of Mirai-greeth_flood:
# flow_duration                     0.0
# Header_Length                     0.0
# Protocol Type                    47.0
# Duration                         64.0
# Rate                         2.414953
# Srate                        2.414953
# Drate                             0.0
# fin_flag_number                   0.0
# syn_flag_number                   0.0
# rst_flag_number                   0.0
# psh_flag_number                   0.0
# ack_flag_number                   0.0
# ece_flag_number                   0.0
# cwr_flag_number                   0.0
# ack_count                         0.0
# syn_count                         0.0
# fin_count                         0.0
# urg_count                         0.0
# rst_count                         0.0
# HTTP                              0.0
# HTTPS                             0.0
# DNS                               0.0
# Telnet                            0.0
# SMTP                              0.0
# SSH                               0.0
# IRC                               0.0
# TCP                               0.0
# UDP                               0.0
# DHCP                              0.0
# ARP                               0.0
# ICMP                              0.0
# IPv                               1.0
# LLC                               1.0
# Tot sum                        6216.0
# Min                             592.0
# Max                             592.0
# AVG                             592.0
# Std                               0.0
# Tot size                        592.0
# IAT                   83681204.020507
# Number                            9.5
# Magnitue                    34.409301
# Radius                            0.0
# Covariance                        0.0
# Variance                          0.0
# Weight                         141.55
# label              Mirai-greeth_flood
# Name: 31, dtype: object
# First instance of DoS-TCP_Flood:
# flow_duration             5.023736
# Header_Length                108.0
# Protocol Type                  6.0
# Duration                      64.0
# Rate                       0.39811
# Srate                      0.39811
# Drate                          0.0
# fin_flag_number                0.0
# syn_flag_number                0.0
# rst_flag_number                0.0
# psh_flag_number                0.0
# ack_flag_number                0.0
# ece_flag_number                0.0
# cwr_flag_number                0.0
# ack_count                      0.0
# syn_count                      0.0
# fin_count                      0.0
# urg_count                      0.0
# rst_count                      0.0
# HTTP                           0.0
# HTTPS                          0.0
# DNS                            0.0
# Telnet                         0.0
# SMTP                           0.0
# SSH                            0.0
# IRC                            0.0
# TCP                            1.0
# UDP                            0.0
# DHCP                           0.0
# ARP                            0.0
# ICMP                           0.0
# IPv                            1.0
# LLC                            1.0
# Tot sum                      567.0
# Min                           54.0
# Max                           54.0
# AVG                           54.0
# Std                            0.0
# Tot size                      54.0
# IAT                82951169.090463
# Number                         9.5
# Magnitue                 10.392305
# Radius                         0.0
# Covariance                     0.0
# Variance                       0.0
# Weight                      141.55
# label                DoS-TCP_Flood
# Name: 56, dtype: object
# First instance of DictionaryBruteForce:
# flow_duration                154.634979
# Header_Length                   39771.8
# Protocol Type                      12.0
# Duration                          110.2
# Rate                           1.626965
# Srate                          1.626965
# Drate                               0.0
# fin_flag_number                     0.0
# syn_flag_number                     0.0
# rst_flag_number                     0.0
# psh_flag_number                     0.0
# ack_flag_number                     0.0
# ece_flag_number                     0.0
# cwr_flag_number                     0.0
# ack_count                           0.0
# syn_count                           0.8
# fin_count                           0.3
# urg_count                         115.8
# rst_count                         240.7
# HTTP                                0.0
# HTTPS                               0.0
# DNS                                 0.0
# Telnet                              0.0
# SMTP                                0.0
# SSH                                 0.0
# IRC                                 0.0
# TCP                                 0.0
# UDP                                 1.0
# DHCP                                0.0
# ARP                                 0.0
# ICMP                                0.0
# IPv                                 1.0
# LLC                                 1.0
# Tot sum                          1635.2
# Min                                54.0
# Max                               230.0
# AVG                          105.130129
# Std                              62.283
# Tot size                          102.2
# IAT                     166601377.67717
# Number                             13.5
# Magnitue                      14.512621
# Radius                        88.202282
# Covariance                  3900.660861
# Variance                            1.0
# Weight                            244.6
# label              DictionaryBruteForce
# Name: 74, dtype: object
# First instance of DoS-HTTP_Flood:
# flow_duration             5.601808
# Header_Length             14260.23
# Protocol Type                 6.87
# Duration                     76.95
# Rate                      2.491338
# Srate                     2.491338
# Drate                          0.0
# fin_flag_number                0.0
# syn_flag_number                0.0
# rst_flag_number                0.0
# psh_flag_number                0.0
# ack_flag_number                1.0
# ece_flag_number                0.0
# cwr_flag_number                0.0
# ack_count                     0.04
# syn_count                     0.81
# fin_count                      0.0
# urg_count                     2.11
# rst_count                    16.39
# HTTP                           1.0
# HTTPS                          0.0
# DNS                            0.0
# Telnet                         0.0
# SMTP                           0.0
# SSH                            0.0
# IRC                            0.0
# TCP                            1.0
# UDP                            0.0
# DHCP                           0.0
# ARP                            0.0
# ICMP                           0.0
# IPv                            1.0
# LLC                            1.0
# Tot sum                    5300.29
# Min                         283.74
# Max                         901.14
# AVG                     527.077273
# Std                     210.525308
# Tot size                    396.24
# IAT                82998829.192784
# Number                         9.5
# Magnitue                 26.045589
# Radius                  297.447985
# Covariance            132941.42606
# Variance                      0.74
# Weight                      141.55
# label               DoS-HTTP_Flood
# Name: 96, dtype: object
# First instance of DDoS-ICMP_Fragmentation:
# flow_duration                     0.005001
# Header_Length                         9.34
# Protocol Type                         1.04
# Duration                             63.22
# Rate                               5.01596
# Srate                              5.01596
# Drate                                  0.0
# fin_flag_number                        0.0
# syn_flag_number                        0.0
# rst_flag_number                        0.0
# psh_flag_number                        0.0
# ack_flag_number                        0.0
# ece_flag_number                        0.0
# cwr_flag_number                        0.0
# ack_count                             0.02
# syn_count                             0.02
# fin_count                              0.0
# urg_count                             0.02
# rst_count                             0.09
# HTTP                                   0.0
# HTTPS                                  0.0
# DNS                                    0.0
# Telnet                                 0.0
# SMTP                                   0.0
# SSH                                    0.0
# IRC                                    0.0
# TCP                                    0.0
# UDP                                    0.0
# DHCP                                   0.0
# ARP                                    0.0
# ICMP                                   1.0
# IPv                                    1.0
# LLC                                    1.0
# Tot sum                            9301.46
# Min                                  316.7
# Max                                 1456.4
# AVG                             854.053463
# Std                             548.975819
# Tot size                             920.5
# IAT                        83248838.121586
# Number                                 9.5
# Magnitue                         41.124395
# Radius                          776.264813
# Covariance                   317371.106631
# Variance                              0.95
# Weight                              141.55
# label              DDoS-ICMP_Fragmentation
# Name: 174, dtype: object
# First instance of DNS_Spoofing:
# flow_duration               0.0
# Header_Length              94.0
# Protocol Type              17.0
# Duration                   12.0
# Rate                  61.886323
# Srate                 61.886323
# Drate                       0.0
# fin_flag_number             0.0
# syn_flag_number             0.0
# rst_flag_number             0.0
# psh_flag_number             0.0
# ack_flag_number             0.0
# ece_flag_number             0.0
# cwr_flag_number             0.0
# ack_count                   0.0
# syn_count                   0.0
# fin_count                   0.0
# urg_count                   0.0
# rst_count                   0.0
# HTTP                        0.0
# HTTPS                       0.0
# DNS                         0.0
# Telnet                      0.0
# SMTP                        0.0
# SSH                         0.0
# IRC                         0.0
# TCP                         0.0
# UDP                         1.0
# DHCP                        0.0
# ARP                         0.0
# ICMP                        0.0
# IPv                         1.0
# LLC                         1.0
# Tot sum                   517.0
# Min                        94.0
# Max                        94.0
# AVG                        94.0
# Std                         0.0
# Tot size                   94.0
# IAT                    0.000108
# Number                      5.5
# Magnitue              13.711309
# Radius                      0.0
# Covariance                  0.0
# Variance                    0.0
# Weight                     38.5
# label              DNS_Spoofing
# Name: 212, dtype: object
# First instance of Recon-HostDiscovery:
# flow_duration               276.586212
# Header_Length                  34853.1
# Protocol Type                      7.0
# Duration                          78.1
# Rate                          2.973206
# Srate                         2.973206
# Drate                              0.0
# fin_flag_number                    0.0
# syn_flag_number                    0.0
# rst_flag_number                    0.0
# psh_flag_number                    0.0
# ack_flag_number                    1.0
# ece_flag_number                    0.0
# cwr_flag_number                    0.0
# ack_count                          0.1
# syn_count                          0.2
# fin_count                          0.0
# urg_count                        189.0
# rst_count                        330.8
# HTTP                               0.0
# HTTPS                              0.0
# DNS                                0.0
# Telnet                             0.0
# SMTP                               0.0
# SSH                                0.0
# IRC                                0.0
# TCP                                1.0
# UDP                                0.0
# DHCP                               0.0
# ARP                                0.0
# ICMP                               0.0
# IPv                                1.0
# LLC                                1.0
# Tot sum                          486.0
# Min                               54.0
# Max                              151.7
# AVG                          81.682778
# Std                          35.891601
# Tot size                          88.9
# IAT                           0.014835
# Number                             5.5
# Magnitue                     12.709539
# Radius                       50.758389
# Covariance                 1776.265039
# Variance                           0.9
# Weight                            38.5
# label              Recon-HostDiscovery
# Name: 385, dtype: object
# First instance of Recon-PortScan:
# flow_duration          355.014276
# Header_Length              3466.0
# Protocol Type                 6.0
# Duration                     74.3
# Rate                     9.269611
# Srate                    9.269611
# Drate                         0.0
# fin_flag_number               0.0
# syn_flag_number               0.0
# rst_flag_number               0.0
# psh_flag_number               0.0
# ack_flag_number               1.0
# ece_flag_number               0.0
# cwr_flag_number               0.0
# ack_count                     0.2
# syn_count                     0.4
# fin_count                     0.0
# urg_count                    22.1
# rst_count                    48.8
# HTTP                          0.0
# HTTPS                         1.0
# DNS                           0.0
# Telnet                        0.0
# SMTP                          0.0
# SSH                           0.0
# IRC                           0.0
# TCP                           1.0
# UDP                           0.0
# DHCP                          0.0
# ARP                           0.0
# ICMP                          0.0
# IPv                           1.0
# LLC                           1.0
# Tot sum                     383.0
# Min                          66.0
# Max                          75.2
# AVG                     69.165238
# Std                      3.985401
# Tot size                     70.1
# IAT                      0.046315
# Number                        5.5
# Magnitue                11.760811
# Radius                   5.636208
# Covariance               18.28448
# Variance                      0.9
# Weight                       38.5
# label              Recon-PortScan
# Name: 402, dtype: object
# First instance of VulnerabilityScan:
# flow_duration             252.757568
# Header_Length               68068.41
# Protocol Type                   9.63
# Duration                       89.48
# Rate                      174.432397
# Srate                     174.432397
# Drate                            0.0
# fin_flag_number                  0.0
# syn_flag_number                  0.0
# rst_flag_number                  0.0
# psh_flag_number                  0.0
# ack_flag_number                  0.0
# ece_flag_number                  0.0
# cwr_flag_number                  0.0
# ack_count                       0.18
# syn_count                       0.88
# fin_count                       0.06
# urg_count                      79.35
# rst_count                     189.42
# HTTP                             0.0
# HTTPS                            0.0
# DNS                              0.0
# Telnet                           0.0
# SMTP                             0.0
# SSH                              0.0
# IRC                              0.0
# TCP                              1.0
# UDP                              0.0
# DHCP                             0.0
# ARP                              0.0
# ICMP                             0.0
# IPv                              1.0
# LLC                              1.0
# Tot sum                      1232.54
# Min                            60.92
# Max                           281.43
# AVG                       118.169751
# Std                        70.134411
# Tot size                       113.5
# IAT                  83241806.318603
# Number                           9.5
# Magnitue                   15.281773
# Radius                     99.269067
# Covariance               5617.700295
# Variance                        0.94
# Weight                        141.55
# label              VulnerabilityScan
# Name: 719, dtype: object
# First instance of Recon-OSScan:
# flow_duration             20.212106
# Header_Length               18901.8
# Protocol Type                   7.1
# Duration                       64.7
# ...
# Std                       7.208911
# Tot size                     77.79
# IAT                83375303.622126
# Number                         9.5
# Magnitue                 12.475284
# Radius                   10.209686
# Covariance              271.965966
# Variance                      0.89
# Weight                      141.55
# label               DDoS-SlowLoris
# Name: 2032, dtype: object
# First instance of SqlInjection:
# flow_duration           1739.802815
# Header_Length               16223.7
# Protocol Type                   7.1
# Duration                       84.1
# Rate                       9.906078
# Srate                      9.906078
# Drate                           0.0
# fin_flag_number                 0.0
# syn_flag_number                 0.0
# rst_flag_number                 0.0
# psh_flag_number                 0.0
# ack_flag_number                 1.0
# ece_flag_number                 0.0
# cwr_flag_number                 0.0
# ack_count                       0.2
# syn_count                       0.5
# fin_count                       0.0
# urg_count                      38.0
# rst_count                      74.2
# HTTP                            0.0
# HTTPS                           0.0
# DNS                             0.0
# Telnet                          0.0
# SMTP                            0.0
# SSH                             0.0
# IRC                             0.0
# TCP                             1.0
# UDP                             0.0
# DHCP                            0.0
# ARP                             0.0
# ICMP                            0.0
# IPv                             1.0
# LLC                             1.0
# Tot sum                      2199.4
# Min                            66.0
# Max                           511.2
# AVG                      141.753986
# Std                      122.139699
# Tot size                      169.7
# IAT                166482032.077995
# Number                         13.5
# Magnitue                  16.852109
# Radius                   173.199044
# Covariance             15803.513622
# Variance                        1.0
# Weight                        244.6
# label                  SqlInjection
# Name: 2168, dtype: object
# First instance of DDoS-HTTP_Flood:
# flow_duration              5.64534
# Header_Length              4525.24
# Protocol Type                 6.66
# Duration                      68.7
# Rate                      5.901243
# Srate                     5.901243
# Drate                          0.0
# fin_flag_number                0.0
# syn_flag_number                0.0
# rst_flag_number                0.0
# psh_flag_number                0.0
# ack_flag_number                1.0
# ece_flag_number                0.0
# cwr_flag_number                0.0
# ack_count                     0.27
# syn_count                     3.08
# fin_count                     0.77
# urg_count                     2.15
# rst_count                     7.73
# HTTP                           1.0
# HTTPS                          0.0
# DNS                            0.0
# Telnet                         0.0
# SMTP                           0.0
# SSH                            0.0
# IRC                            0.0
# TCP                            1.0
# UDP                            0.0
# DHCP                           0.0
# ARP                            0.0
# ICMP                           0.0
# IPv                            1.0
# LLC                            1.0
# Tot sum                    3077.61
# Min                         115.76
# Max                         991.72
# AVG                     320.138322
# Std                     308.300077
# Tot size                    259.04
# IAT                83158165.381568
# Number                         9.5
# Magnitue                 22.970146
# Radius                   436.53788
# Covariance           152597.998489
# Variance                      0.88
# Weight                      141.55
# label              DDoS-HTTP_Flood
# Name: 3000, dtype: object
# First instance of Recon-PingSweep:
# flow_duration             0.959376
# Header_Length              91234.8
# Protocol Type                  6.0
# Duration                      92.8
# Rate                     70.279908
# Srate                    70.279908
# Drate                          0.0
# fin_flag_number                0.0
# syn_flag_number                0.0
# rst_flag_number                0.0
# psh_flag_number                0.0
# ack_flag_number                1.0
# ece_flag_number                0.0
# cwr_flag_number                0.0
# ack_count                      0.0
# syn_count                      2.0
# fin_count                      0.0
# urg_count                      5.9
# rst_count                     76.8
# HTTP                           0.0
# HTTPS                          1.0
# DNS                            0.0
# Telnet                         0.0
# SMTP                           0.0
# SSH                            0.0
# IRC                            0.0
# TCP                            1.0
# UDP                            0.0
# DHCP                           0.0
# ARP                            0.0
# ICMP                           0.0
# IPv                            1.0
# LLC                            1.0
# Tot sum                    15489.4
# Min                         1372.8
# Max                         4288.0
# AVG                    2989.374286
# Std                    1050.097826
# Tot size                    2247.6
# IAT                       0.000209
# Number                         5.5
# Magnitue                 77.129571
# Radius                 1485.062588
# Covariance          1317939.383864
# Variance                       0.9
# Weight                        38.5
# label              Recon-PingSweep
# Name: 5268, dtype: object
# First instance of BrowserHijacking:
# flow_duration            213.583798
# Header_Length               11189.9
# Protocol Type                  10.4
# Duration                      112.6
# Rate                      33.999425
# Srate                     33.999425
# Drate                           0.0
# fin_flag_number                 0.0
# syn_flag_number                 0.0
# rst_flag_number                 0.0
# psh_flag_number                 0.0
# ack_flag_number                 0.0
# ece_flag_number                 0.0
# cwr_flag_number                 0.0
# ack_count                       0.0
# syn_count                       0.8
# fin_count                       0.0
# urg_count                      52.7
# rst_count                      87.3
# HTTP                            0.0
# HTTPS                           1.0
# DNS                             0.0
# Telnet                          0.0
# SMTP                            0.0
# SSH                             0.0
# IRC                             0.0
# TCP                             1.0
# UDP                             0.0
# DHCP                            0.0
# ARP                             0.0
# ICMP                            0.0
# IPv                             1.0
# LLC                             1.0
# Tot sum                      1891.9
# Min                            66.0
# Max                           309.5
# AVG                      121.182591
# Std                       70.268325
# Tot size                      141.2
# IAT                166845873.627506
# Number                         13.5
# Magnitue                  15.558269
# Radius                    99.666704
# Covariance              5200.269487
# Variance                        1.0
# Weight                        244.6
# label              BrowserHijacking
# Name: 5577, dtype: object
# First instance of XSS:
# flow_duration            92.499937
# Header_Length               4763.5
# Protocol Type                 10.4
# Duration                     111.9
# Rate                      3.668685
# Srate                     3.668685
# Drate                          0.0
# fin_flag_number                0.0
# syn_flag_number                0.0
# rst_flag_number                0.0
# psh_flag_number                0.0
# ack_flag_number                0.0
# ece_flag_number                0.0
# cwr_flag_number                0.0
# ack_count                      0.0
# syn_count                      0.3
# fin_count                      0.0
# urg_count                     15.4
# rst_count                     33.0
# HTTP                           0.0
# HTTPS                          1.0
# DNS                            0.0
# Telnet                         0.0
# SMTP                           0.0
# SSH                            0.0
# IRC                            0.0
# TCP                            1.0
# UDP                            0.0
# DHCP                           0.0
# ARP                            0.0
# ICMP                           0.0
# IPv                            1.0
# LLC                            1.0
# Tot sum                     3653.0
# Min                           58.0
# Max                          715.0
# AVG                     237.854834
# Std                     208.621914
# Tot size                     170.7
# IAT                167639168.91523
# Number                        13.5
# Magnitue                  21.80949
# Radius                  295.711784
# Covariance             43890.45025
# Variance                       1.0
# Weight                       244.6
# label                          XSS
# Name: 6189, dtype: object
# First instance of Uploading_Attack:
# flow_duration              1.333854
# Header_Length              107972.0
# Protocol Type                   6.0
# Duration                      112.0
# Rate                       72.34613
# Srate                      72.34613
# Drate                           0.0
# fin_flag_number                 0.0
# syn_flag_number                 0.0
# rst_flag_number                 0.0
# psh_flag_number                 0.0
# ack_flag_number                 1.0
# ece_flag_number                 0.0
# cwr_flag_number                 0.0
# ack_count                       0.0
# syn_count                       2.0
# fin_count                       0.0
# urg_count                       5.0
# rst_count                      95.5
# HTTP                            0.0
# HTTPS                           1.0
# DNS                             0.0
# Telnet                          0.0
# SMTP                            0.0
# SSH                             0.0
# IRC                             0.0
# TCP                             1.0
# UDP                             0.0
# DHCP                            0.0
# ARP                             0.0
# ICMP                            0.0
# IPv                             1.0
# LLC                             1.0
# Tot sum                     23467.0
# Min                          1514.0
# Max                          1514.0
# AVG                          1514.0
# Std                             0.0
# Tot size                     1514.0
# IAT                167639391.262458
# Number                         13.5
# Magnitue                  55.027266
# Radius                          0.0
# Covariance                      0.0
# Variance                        0.0
# Weight                        244.6
# label              Uploading_Attack
# Name: 21745, dtype: object
# Real data:
#         flow_duration  Header_Length  Protocol Type  Duration         Rate  \
# 164260       0.147075       21224.00          17.00     64.00  4376.083823
# 159703       0.009695          69.94           6.22     63.62   133.539945
#
#               Srate  Drate  fin_flag_number  syn_flag_number  rst_flag_number  \
# 164260  4376.083823    0.0              0.0              0.0              0.0
# 159703   133.539945    0.0              0.0              1.0              0.0
#
#         ...       Std  Tot size           IAT  Number   Magnitue    Radius  \
# 164260  ...  0.000000     50.00  8.309876e+07     9.5  10.000000  0.000000
# 159703  ...  2.328323     54.92  8.309331e+07     9.5  10.483598  3.298447
#
#         Covariance  Variance  Weight           label
# 164260    0.000000      0.00  141.55  DDoS-UDP_Flood
# 159703   26.885065      0.22  141.55  DDoS-SYN_Flood
#
# [2 rows x 47 columns]
# (1385251, 47)
# There are 34 unique labels in the dataset.
# label
# DDoS-ICMP_Flood            214016
# DDoS-UDP_Flood             160168
# DDoS-TCP_Flood             134336
# DDoS-PSHACK_Flood          120838
# DDoS-SYN_Flood             120781
# DDoS-RSTFINFlood           119609
# DDoS-SynonymousIP_Flood    106445
# DoS-UDP_Flood               98625
# DoS-TCP_Flood               78976
# DoS-SYN_Flood               59777
# BenignTraffic               32763
# Mirai-greeth_flood          29566
# Mirai-udpplain              26636
# Mirai-greip_flood           22088
# DDoS-ICMP_Fragmentation     13590
# MITM-ArpSpoofing             9133
# DDoS-UDP_Fragmentation       8512
# DDoS-ACK_Fragmentation       8433
# DNS_Spoofing                 5463
# Recon-HostDiscovery          4008
# Recon-OSScan                 2957
# Recon-PortScan               2449
# DoS-HTTP_Flood               2234
# VulnerabilityScan            1136
# DDoS-HTTP_Flood               886
# DDoS-SlowLoris                684
# DictionaryBruteForce          370
# BrowserHijacking              168
# CommandInjection              147
# SqlInjection                  130
# XSS                           119
# Backdoor_Malware               97
# Recon-PingSweep                71
# Uploading_Attack               40
# Name: count, dtype: int64
#        flow_duration  Header_Length  Protocol Type      Duration  \
# count   1.385251e+06   1.385251e+06   1.385251e+06  1.385251e+06
# mean    6.086423e+00   7.727262e+04   9.064225e+00  6.635857e+01
# std     3.355535e+02   4.645398e+05   8.948236e+00  1.406328e+01
# min     0.000000e+00   0.000000e+00   0.000000e+00  0.000000e+00
# 25%     0.000000e+00   5.400000e+01   6.000000e+00  6.400000e+01
# 50%     0.000000e+00   5.400000e+01   6.000000e+00  6.400000e+01
# 75%     1.050667e-01   2.859900e+02   1.433000e+01  6.400000e+01
# max     2.181134e+05   9.795649e+06   4.700000e+01  2.550000e+02
#
#                Rate         Srate         Drate  fin_flag_number  \
# count  1.385251e+06  1.385251e+06  1.385251e+06     1.385251e+06
# mean   9.136173e+03  9.136173e+03  6.516857e-06     8.627390e-02
# std    1.002872e+05  1.002872e+05  4.418687e-03     2.807682e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00     0.000000e+00
# 25%    2.100169e+00  2.100169e+00  0.000000e+00     0.000000e+00
# 50%    1.579307e+01  1.579307e+01  0.000000e+00     0.000000e+00
# 75%    1.171712e+02  1.171712e+02  0.000000e+00     0.000000e+00
# max    8.388608e+06  8.388608e+06  5.022185e+00     1.000000e+00
#
#        syn_flag_number  rst_flag_number  ...           AVG           Std  \
# count     1.385251e+06     1.385251e+06  ...  1.385251e+06  1.385251e+06
# mean      2.070881e-01     9.023924e-02  ...  1.249866e+02  3.342434e+01
# std       4.052194e-01     2.865243e-01  ...  2.416227e+02  1.605632e+02
# min       0.000000e+00     0.000000e+00  ...  4.200000e+01  0.000000e+00
# 25%       0.000000e+00     0.000000e+00  ...  5.000000e+01  0.000000e+00
# 50%       0.000000e+00     0.000000e+00  ...  5.400000e+01  0.000000e+00
# 75%       0.000000e+00     0.000000e+00  ...  5.405258e+01  3.719096e-01
# max       1.000000e+00     1.000000e+00  ...  8.201775e+03  8.643503e+03
#
#            Tot size           IAT        Number      Magnitue        Radius  \
# count  1.385251e+06  1.385251e+06  1.385251e+06  1.385251e+06  1.385251e+06
# mean   1.250793e+02  8.318933e+07  9.498798e+00  1.313377e+01  4.723296e+01
# std    2.426297e+02  1.710092e+07  8.217052e-01  8.646518e+00  2.270902e+02
# min    4.200000e+01  0.000000e+00  1.000000e+00  9.165151e+00  0.000000e+00
# 25%    5.000000e+01  8.307156e+07  9.500000e+00  1.000000e+01  0.000000e+00
# 50%    5.400000e+01  8.312452e+07  9.500000e+00  1.039230e+01  0.000000e+00
# 75%    5.406000e+01  8.334390e+07  9.500000e+00  1.039675e+01  5.059213e-01
# max    8.754000e+03  1.676394e+08  1.500000e+01  1.280783e+02  1.222376e+04
#
#          Covariance      Variance        Weight
# count  1.385251e+06  1.385251e+06  1.385251e+06
# mean   3.082499e+04  9.656077e-02  1.415206e+02
# std    3.273916e+05  2.332904e-01  2.113469e+01
# min    0.000000e+00  0.000000e+00  1.000000e+00
# 25%    0.000000e+00  0.000000e+00  1.415500e+02
# 50%    0.000000e+00  0.000000e+00  1.415500e+02
# 75%    1.344216e+00  8.000000e-02  1.415500e+02
# max    8.561022e+07  1.000000e+00  2.446000e+02
#
# [8 rows x 46 columns]

# %% [markdown]
# # Preprocessing
# ## Encoding Labels

# %%
label_encoder = LabelEncoder()
full_data['label'] = label_encoder.fit_transform(full_data['label'])

# Store label mappings
label_mapping = {index: label for index, label in enumerate(label_encoder.classes_)}
print("Label mappings:", label_mapping)

# Retrieve the numeric codes for classes
class_codes = {label: label_encoder.transform([label])[0] for label in label_encoder.classes_}

# Print specific instances after label encoding
print("After encoding:")
for label, code in class_codes.items():
    # Print the first instance of each class
    print(f"First instance of {label} (code {code}):")
    print(full_data[full_data['label'] == code].iloc[0])
# Out:
# Label mappings: {0: 'Backdoor_Malware', 1: 'BenignTraffic', 2: 'BrowserHijacking', 3: 'CommandInjection', 4: 'DDoS-ACK_Fragmentation', 5: 'DDoS-HTTP_Flood', 6: 'DDoS-ICMP_Flood', 7: 'DDoS-ICMP_Fragmentation', 8: 'DDoS-PSHACK_Flood', 9: 'DDoS-RSTFINFlood', 10: 'DDoS-SYN_Flood', 11: 'DDoS-SlowLoris', 12: 'DDoS-SynonymousIP_Flood', 13: 'DDoS-TCP_Flood', 14: 'DDoS-UDP_Flood', 15: 'DDoS-UDP_Fragmentation', 16: 'DNS_Spoofing', 17: 'DictionaryBruteForce', 18: 'DoS-HTTP_Flood', 19: 'DoS-SYN_Flood', 20: 'DoS-TCP_Flood', 21: 'DoS-UDP_Flood', 22: 'MITM-ArpSpoofing', 23: 'Mirai-greeth_flood', 24: 'Mirai-greip_flood', 25: 'Mirai-udpplain', 26: 'Recon-HostDiscovery', 27: 'Recon-OSScan', 28: 'Recon-PingSweep', 29: 'Recon-PortScan', 30: 'SqlInjection', 31: 'Uploading_Attack', 32: 'VulnerabilityScan', 33: 'XSS'}
# After encoding:
# First instance of Backdoor_Malware (code 0):
# flow_duration      1.972717e+02
# Header_Length      1.170530e+04
# Protocol Type      6.000000e+00
# Duration           1.047000e+02
# Rate               7.584542e+01
# Srate              7.584542e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          1.700000e+00
# fin_count          0.000000e+00
# urg_count          3.580000e+01
# rst_count          5.720000e+01
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            7.076400e+03
# Min                5.400000e+01
# Max                1.494000e+03
# AVG                4.677928e+02
# Std                5.882289e+02
# Tot size           1.474000e+02
# IAT                1.676299e+08
# Number             1.350000e+01
# Magnitue           3.058128e+01
# Radius             8.331585e+02
# Covariance         3.482747e+05
# Variance           1.000000e+00
# Weight             2.446000e+02
# label              0.000000e+00
# Name: 200186, dtype: float64
# First instance of BenignTraffic (code 1):
# flow_duration        26.190505
# Header_Length      4126.300000
# Protocol Type         7.100000
# Duration             72.400000
# Rate                 13.020830
# Srate                13.020830
# Drate                 0.000000
# fin_flag_number       0.000000
# syn_flag_number       0.000000
# rst_flag_number       0.000000
# psh_flag_number       0.000000
# ack_flag_number       1.000000
# ece_flag_number       0.000000
# cwr_flag_number       0.000000
# ack_count             0.500000
# syn_count             1.400000
# fin_count             0.000000
# urg_count            10.900000
# rst_count            20.900000
# HTTP                  0.000000
# HTTPS                 1.000000
# DNS                   0.000000
# Telnet                0.000000
# SMTP                  0.000000
# SSH                   0.000000
# IRC                   0.000000
# TCP                   1.000000
# UDP                   0.000000
# DHCP                  0.000000
# ARP                   0.000000
# ICMP                  0.000000
# IPv                   1.000000
# LLC                   1.000000
# Tot sum             514.900000
# Min                  59.500000
# Max                 145.800000
# AVG                  92.348016
# Std                  35.891236
# Tot size             86.800000
# IAT                   0.016969
# Number                5.500000
# Magnitue             13.553991
# Radius               50.757873
# Covariance         1588.702860
# Variance              0.900000
# Weight               38.500000
# label                 1.000000
# Name: 103668, dtype: float64
# First instance of BrowserHijacking (code 2):
# flow_duration      1.090468e-01
# Header_Length      5.617700e+03
# Protocol Type      9.300000e+00
# Duration           1.256000e+02
# Rate               1.027051e+02
# Srate              1.027051e+02
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          2.000000e-01
# syn_count          1.400000e+00
# fin_count          0.000000e+00
# urg_count          4.100000e+00
# rst_count          1.120000e+01
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            7.756300e+03
# Min                6.600000e+01
# Max                2.922000e+03
# AVG                5.105510e+02
# Std                7.741984e+02
# Tot size           1.927000e+02
# IAT                1.668458e+08
# Number             1.350000e+01
# Magnitue           3.197079e+01
# Radius             1.096741e+03
# Covariance         6.045678e+05
# Variance           1.000000e+00
# Weight             2.446000e+02
# label              2.000000e+00
# Name: 311378, dtype: float64
# First instance of CommandInjection (code 3):
# flow_duration        444.356065
# Header_Length      20816.300000
# Protocol Type         14.800000
# Duration             112.800000
# Rate                  75.500142
# Srate                 75.500142
# Drate                  0.000000
# fin_flag_number        0.000000
# syn_flag_number        0.000000
# rst_flag_number        0.000000
# psh_flag_number        0.000000
# ack_flag_number        0.000000
# ece_flag_number        0.000000
# cwr_flag_number        0.000000
# ack_count              0.000000
# syn_count              0.000000
# fin_count              0.000000
# urg_count             74.000000
# rst_count            162.900000
# HTTP                   0.000000
# HTTPS                  0.000000
# DNS                    0.000000
# Telnet                 0.000000
# SMTP                   0.000000
# SSH                    0.000000
# IRC                    0.000000
# TCP                    0.000000
# UDP                    1.000000
# DHCP                   0.000000
# ARP                    0.000000
# ICMP                   0.000000
# IPv                    1.000000
# LLC                    1.000000
# Tot sum              628.000000
# Min                   89.600000
# Max                  214.000000
# AVG                  133.341349
# Std                   44.100552
# Tot size              91.600000
# IAT                    0.008188
# Number                 5.500000
# Magnitue              16.171538
# Radius                62.367599
# Covariance          2208.026580
# Variance               0.900000
# Weight                38.500000
# label                  3.000000
# Name: 86079, dtype: float64
# First instance of DDoS-ACK_Fragmentation (code 4):
# flow_duration      7.764101e-05
# Header_Length      7.294400e+02
# Protocol Type      6.000000e+00
# Duration           6.747000e+01
# Rate               2.103900e+02
# Srate              2.103900e+02
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          1.000000e-02
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          5.200000e-01
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            9.264960e+03
# Min                3.006400e+02
# Max                1.457000e+03
# AVG                8.490063e+02
# Std                5.448323e+02
# Tot size           9.120400e+02
# IAT                8.333556e+07
# Number             9.500000e+00
# Magnitue           4.100398e+01
# Radius             7.704684e+02
# Covariance         3.127234e+05
# Variance           9.500000e-01
# Weight             1.415500e+02
# label              4.000000e+00
# Name: 220476, dtype: float64
# First instance of DDoS-HTTP_Flood (code 5):
# flow_duration      1.334276e+01
# Header_Length      6.152400e+02
# Protocol Type      6.220000e+00
# Duration           6.973000e+01
# Rate               1.165188e+00
# Srate              1.165188e+00
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          1.300000e-01
# syn_count          1.390000e+00
# fin_count          2.700000e-01
# urg_count          5.800000e-01
# rst_count          5.160000e+00
# HTTP               1.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            1.205980e+03
# Min                6.945000e+01
# Max                2.693900e+02
# AVG                1.191862e+02
# Std                7.864643e+01
# Tot size           1.162700e+02
# IAT                8.339179e+07
# Number             9.500000e+00
# Magnitue           1.491267e+01
# Radius             1.110855e+02
# Covariance         1.488323e+04
# Variance           9.000000e-01
# Weight             1.415500e+02
# label              5.000000e+00
# Name: 117710, dtype: float64
# First instance of DDoS-ICMP_Flood (code 6):
# flow_duration      2.205978e-01
# Header_Length      1.559263e+04
# Protocol Type      1.450000e+00
# Duration           6.400000e+01
# Rate               5.993260e+01
# Srate              5.993260e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          5.400000e-01
# rst_count          1.710000e+01
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               1.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            1.337720e+03
# Min                4.200000e+01
# Max                5.265600e+02
# AVG                1.019932e+02
# Std                1.458408e+02
# Tot size           1.889600e+02
# IAT                8.313249e+07
# Number             9.500000e+00
# Magnitue           1.276269e+01
# Radius             2.063881e+02
# Covariance         8.321010e+04
# Variance           2.800000e-01
# Weight             1.415500e+02
# label              6.000000e+00
# Name: 235836, dtype: float64
# First instance of DDoS-ICMP_Fragmentation (code 7):
# flow_duration      1.319586e-02
# Header_Length      1.980000e+00
# Protocol Type      1.040000e+00
# Duration           6.444000e+01
# Rate               1.769028e+01
# Srate              1.769028e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          3.000000e-02
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               1.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            9.622240e+03
# Min                3.274800e+02
# Max                1.479440e+03
# AVG                9.237231e+02
# Std                5.422111e+02
# Tot size           9.037000e+02
# IAT                8.324945e+07
# Number             9.500000e+00
# Magnitue           4.281088e+01
# Radius             7.668686e+02
# Covariance         3.130765e+05
# Variance           9.400000e-01
# Weight             1.415500e+02
# label              7.000000e+00
# Name: 60400, dtype: float64
# First instance of DDoS-PSHACK_Flood (code 8):
# flow_duration      0.000000e+00
# Header_Length      5.400000e+01
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               2.459144e+01
# Srate              2.459144e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    1.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          1.000000e+00
# rst_count          1.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.670000e+02
# Min                5.400000e+01
# Max                5.400000e+01
# AVG                5.400000e+01
# Std                0.000000e+00
# Tot size           5.400000e+01
# IAT                8.331382e+07
# Number             9.500000e+00
# Magnitue           1.039230e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              8.000000e+00
# Name: 19270, dtype: float64
# First instance of DDoS-RSTFINFlood (code 9):
# flow_duration      0.000000e+00
# Header_Length      5.400000e+01
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               3.814828e+00
# Srate              3.814828e+00
# Drate              0.000000e+00
# fin_flag_number    1.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    1.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          1.000000e+00
# syn_count          0.000000e+00
# fin_count          1.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.670000e+02
# Min                5.400000e+01
# Max                5.400000e+01
# AVG                5.400000e+01
# Std                0.000000e+00
# Tot size           5.400000e+01
# IAT                8.334374e+07
# Number             9.500000e+00
# Magnitue           1.039230e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              9.000000e+00
# Name: 228823, dtype: float64
# First instance of DDoS-SYN_Flood (code 10):
# flow_duration      9.695020e-03
# Header_Length      6.994000e+01
# Protocol Type      6.220000e+00
# Duration           6.362000e+01
# Rate               1.335399e+02
# Srate              1.335399e+02
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    1.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          2.000000e-02
# syn_count          1.020000e+00
# fin_count          0.000000e+00
# urg_count          2.000000e-02
# rst_count          1.100000e-01
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.759800e+02
# Min                5.400000e+01
# Max                6.202000e+01
# AVG                5.497348e+01
# Std                2.328323e+00
# Tot size           5.492000e+01
# IAT                8.309331e+07
# Number             9.500000e+00
# Magnitue           1.048360e+01
# Radius             3.298447e+00
# Covariance         2.688507e+01
# Variance           2.200000e-01
# Weight             1.415500e+02
# label              1.000000e+01
# Name: 159703, dtype: float64
# First instance of DDoS-SlowLoris (code 11):
# flow_duration      8.364259e+01
# Header_Length      6.885078e+05
# Protocol Type      6.550000e+00
# Duration           1.153100e+02
# Rate               2.447222e+01
# Srate              2.447222e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          1.700000e-01
# syn_count          1.610000e+00
# fin_count          2.000000e-02
# urg_count          8.471000e+01
# rst_count          7.758700e+02
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            3.368780e+03
# Min                5.960000e+01
# Max                9.464900e+02
# AVG                2.419640e+02
# Std                2.524711e+02
# Tot size           4.106600e+02
# IAT                8.337549e+07
# Number             9.500000e+00
# Magnitue           1.880095e+01
# Radius             3.575982e+02
# Covariance         2.452280e+05
# Variance           9.300000e-01
# Weight             1.415500e+02
# label              1.100000e+01
# Name: 2586, dtype: float64
# First instance of DDoS-SynonymousIP_Flood (code 12):
# flow_duration      0.000000e+00
# Header_Length      5.400000e+01
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               6.577443e+01
# Srate              6.577443e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    1.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          1.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.670000e+02
# Min                5.400000e+01
# Max                5.400000e+01
# AVG                5.400000e+01
# Std                0.000000e+00
# Tot size           5.400000e+01
# IAT                8.336248e+07
# Number             9.500000e+00
# Magnitue           1.039230e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              1.200000e+01
# Name: 141604, dtype: float64
# First instance of DDoS-TCP_Flood (code 13):
# flow_duration      0.000000e+00
# Header_Length      5.400000e+01
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               1.533302e+00
# Srate              1.533302e+00
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.670000e+02
# Min                5.400000e+01
# Max                5.400000e+01
# AVG                5.400000e+01
# Std                0.000000e+00
# Tot size           5.400000e+01
# IAT                8.307238e+07
# Number             9.500000e+00
# Magnitue           1.039230e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              1.300000e+01
# Name: 56911, dtype: float64
# First instance of DDoS-UDP_Flood (code 14):
# flow_duration      1.470754e-01
# Header_Length      2.122400e+04
# Protocol Type      1.700000e+01
# Duration           6.400000e+01
# Rate               4.376084e+03
# Srate              4.376084e+03
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                1.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.250000e+02
# Min                5.000000e+01
# Max                5.000000e+01
# AVG                5.000000e+01
# Std                0.000000e+00
# Tot size           5.000000e+01
# IAT                8.309876e+07
# Number             9.500000e+00
# Magnitue           1.000000e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              1.400000e+01
# Name: 164260, dtype: float64
# First instance of DDoS-UDP_Fragmentation (code 15):
# flow_duration      1.630439e+00
# Header_Length      2.597721e+05
# Protocol Type      1.649000e+01
# Duration           6.208000e+01
# Rate               9.252092e+01
# Srate              9.252092e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            9.585600e+03
# Min                3.337000e+02
# Max                1.479440e+03
# AVG                9.091667e+02
# Std                5.515897e+02
# Tot size           9.174200e+02
# IAT                8.337099e+07
# Number             9.500000e+00
# Magnitue           4.248380e+01
# Radius             7.800758e+02
# Covariance         3.206695e+05
# Variance           9.500000e-01
# Weight             1.415500e+02
# label              1.500000e+01
# Name: 41683, dtype: float64
# First instance of DNS_Spoofing (code 16):
# flow_duration      3.419706e+01
# Header_Length      1.082970e+04
# Protocol Type      7.100000e+00
# Duration           9.090000e+01
# Rate               5.388059e+00
# Srate              5.388059e+00
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          6.000000e-01
# fin_count          0.000000e+00
# urg_count          4.980000e+01
# rst_count          9.410000e+01
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            1.758900e+03
# Min                5.000000e+01
# Max                3.824000e+02
# AVG                1.124919e+02
# Std                8.576619e+01
# Tot size           1.386000e+02
# IAT                1.668617e+08
# Number             1.350000e+01
# Magnitue           1.500028e+01
# Radius             1.214987e+02
# Covariance         7.578761e+03
# Variance           1.000000e+00
# Weight             2.446000e+02
# label              1.600000e+01
# Name: 109772, dtype: float64
# First instance of DictionaryBruteForce (code 17):
# flow_duration      9.111310e+01
# Header_Length      1.259880e+04
# Protocol Type      1.200000e+01
# Duration           6.360000e+01
# Rate               1.309183e+01
# Srate              1.309183e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          2.000000e-01
# fin_count          0.000000e+00
# urg_count          8.500000e+00
# rst_count          1.320000e+01
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                1.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            1.317200e+03
# Min                5.000000e+01
# Max                2.300000e+02
# AVG                8.566980e+01
# Std                4.838939e+01
# Tot size           6.600000e+01
# IAT                1.666013e+08
# Number             1.350000e+01
# Magnitue           1.308808e+01
# Radius             6.859102e+01
# Covariance         2.363559e+03
# Variance           1.000000e+00
# Weight             2.446000e+02
# label              1.700000e+01
# Name: 16340, dtype: float64
# First instance of DoS-HTTP_Flood (code 18):
# flow_duration      3.368905e+00
# Header_Length      1.269835e+04
# Protocol Type      6.110000e+00
# Duration           7.100000e+01
# Rate               5.171321e+00
# Srate              5.171321e+00
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          1.100000e-01
# syn_count          2.720000e+00
# fin_count          5.600000e-01
# urg_count          5.590000e+00
# rst_count          1.074000e+01
# HTTP               1.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            7.649200e+03
# Min                1.632800e+02
# Max                1.736180e+03
# AVG                7.955889e+02
# Std                5.896520e+02
# Tot size           6.677200e+02
# IAT                8.299920e+07
# Number             9.500000e+00
# Magnitue           3.488425e+01
# Radius             8.347587e+02
# Covariance         6.038505e+05
# Variance           7.700000e-01
# Weight             1.415500e+02
# label              1.800000e+01
# Name: 224759, dtype: float64
# First instance of DoS-SYN_Flood (code 19):
# flow_duration      1.058277e-01
# Header_Length      2.660300e+02
# Protocol Type      6.110000e+00
# Duration           6.812000e+01
# Rate               4.543749e+00
# Srate              4.543749e+00
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    1.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          1.100000e+00
# fin_count          0.000000e+00
# urg_count          3.000000e-02
# rst_count          3.200000e-01
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            9.185500e+02
# Min                5.424000e+01
# Max                2.890200e+02
# AVG                8.691676e+01
# Std                7.020293e+01
# Tot size           7.630000e+01
# IAT                8.298597e+07
# Number             9.500000e+00
# Magnitue           1.236301e+01
# Radius             9.939445e+01
# Covariance         3.115835e+04
# Variance           1.800000e-01
# Weight             1.415500e+02
# label              1.900000e+01
# Name: 252669, dtype: float64
# First instance of DoS-TCP_Flood (code 20):
# flow_duration      0.000000e+00
# Header_Length      5.400000e+01
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               1.253164e+00
# Srate              1.253164e+00
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               1.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.670000e+02
# Min                5.400000e+01
# Max                5.400000e+01
# AVG                5.400000e+01
# Std                0.000000e+00
# Tot size           5.400000e+01
# IAT                8.292508e+07
# Number             9.500000e+00
# Magnitue           1.039230e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              2.000000e+01
# Name: 31386, dtype: float64
# First instance of DoS-UDP_Flood (code 21):
# flow_duration      3.854901e-02
# Header_Length      3.577500e+04
# Protocol Type      1.700000e+01
# Duration           6.400000e+01
# Rate               1.855504e+04
# Srate              1.855504e+04
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                1.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.250000e+02
# Min                5.000000e+01
# Max                5.000000e+01
# AVG                5.000000e+01
# Std                0.000000e+00
# Tot size           5.000000e+01
# IAT                8.303326e+07
# Number             9.500000e+00
# Magnitue           1.000000e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              2.100000e+01
# Name: 244149, dtype: float64
# First instance of MITM-ArpSpoofing (code 22):
# flow_duration      4.284638e+00
# Header_Length      2.456231e+06
# Protocol Type      6.000000e+00
# Duration           1.077000e+02
# Rate               4.385735e+02
# Srate              4.385735e+02
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          1.000000e-01
# syn_count          4.000000e-01
# fin_count          0.000000e+00
# urg_count          9.227000e+02
# rst_count          2.063100e+03
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            1.267860e+04
# Min                4.752000e+02
# Max                4.266000e+03
# AVG                2.402882e+03
# Std                1.657895e+03
# Tot size           2.101600e+03
# IAT                3.280878e-04
# Number             5.500000e+00
# Magnitue           6.867478e+01
# Radius             2.344618e+03
# Covariance         3.070751e+06
# Variance           9.000000e-01
# Weight             3.850000e+01
# label              2.200000e+01
# Name: 182162, dtype: float64
# First instance of Mirai-greeth_flood (code 23):
# flow_duration      0.000000e+00
# Header_Length      0.000000e+00
# Protocol Type      4.653000e+01
# Duration           6.336000e+01
# Rate               2.333124e+01
# Srate              2.333124e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            6.194720e+03
# Min                5.707200e+02
# Max                5.920000e+02
# AVG                5.908455e+02
# Std                4.817778e+00
# Tot size           5.866800e+02
# IAT                8.367764e+07
# Number             9.500000e+00
# Magnitue           3.437491e+01
# Radius             6.853633e+00
# Covariance         5.874317e+02
# Variance           4.000000e-02
# Weight             1.415500e+02
# label              2.300000e+01
# Name: 156912, dtype: float64
# First instance of Mirai-greip_flood (code 24):
# flow_duration      2.541252e-02
# Header_Length      1.164000e+01
# Protocol Type      4.450000e+01
# Duration           6.591000e+01
# Rate               2.325545e+02
# Srate              2.325545e+02
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          6.000000e-02
# fin_count          0.000000e+00
# urg_count          1.000000e-02
# rst_count          7.000000e-02
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.990080e+03
# Min                5.090000e+02
# Max                5.784800e+02
# AVG                5.729947e+02
# Std                1.724562e+01
# Tot size           5.675600e+02
# IAT                8.366370e+07
# Number             9.500000e+00
# Magnitue           3.384986e+01
# Radius             2.445546e+01
# Covariance         1.824386e+03
# Variance           1.700000e-01
# Weight             1.415500e+02
# label              2.400000e+01
# Name: 169192, dtype: float64
# First instance of Mirai-udpplain (code 25):
# flow_duration      1.632038e+00
# Header_Length      1.310274e+06
# Protocol Type      1.689000e+01
# Duration           6.567000e+01
# Rate               1.443541e+03
# Srate              1.443541e+03
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          4.000000e-02
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          2.000000e-02
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                1.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.749800e+03
# Min                4.868000e+02
# Max                5.540000e+02
# AVG                5.484908e+02
# Std                1.814348e+01
# Tot size           5.492000e+02
# IAT                8.378456e+07
# Number             9.500000e+00
# Magnitue           3.311731e+01
# Radius             2.569509e+01
# Covariance         2.408433e+03
# Variance           1.400000e-01
# Weight             1.415500e+02
# label              2.500000e+01
# Name: 441637, dtype: float64
# First instance of Recon-HostDiscovery (code 26):
# flow_duration         3.838847
# Header_Length       727.200000
# Protocol Type         5.400000
# Duration             66.000000
# Rate                 16.431245
# Srate                16.431245
# Drate                 0.000000
# fin_flag_number       0.000000
# syn_flag_number       1.000000
# rst_flag_number       0.000000
# psh_flag_number       0.000000
# ack_flag_number       0.000000
# ece_flag_number       0.000000
# cwr_flag_number       0.000000
# ack_count             0.000000
# syn_count             0.700000
# fin_count             0.500000
# urg_count             2.900000
# rst_count             6.200000
# HTTP                  0.000000
# HTTPS                 0.000000
# DNS                   0.000000
# Telnet                0.000000
# SMTP                  0.000000
# SSH                   0.000000
# IRC                   0.000000
# TCP                   1.000000
# UDP                   0.000000
# DHCP                  0.000000
# ARP                   0.000000
# ICMP                  0.000000
# IPv                   1.000000
# LLC                   1.000000
# Tot sum             499.200000
# Min                  56.000000
# Max                 238.800000
# AVG                  90.255556
# Std                  67.178023
# Tot size             80.400000
# IAT                   0.001443
# Number                5.500000
# Magnitue             13.332645
# Radius               95.004072
# Covariance         5767.422956
# Variance              0.800000
# Weight               38.500000
# label                26.000000
# Name: 286050, dtype: float64
# First instance of Recon-OSScan (code 27):
# flow_duration         0.149069
# Header_Length       160.600000
# Protocol Type         6.000000
# Duration             80.900000
# Rate                 21.861794
# Srate                21.861794
# Drate                 0.000000
# fin_flag_number       0.000000
# syn_flag_number       0.000000
# rst_flag_number       1.000000
# psh_flag_number       0.000000
# ack_flag_number       1.000000
# ece_flag_number       0.000000
# cwr_flag_number       0.000000
# ack_count             0.000000
# syn_count             1.300000
# fin_count             0.700000
# urg_count             0.100000
# rst_count             1.300000
# HTTP                  0.000000
# HTTPS                 0.000000
# DNS                   0.000000
# Telnet                0.000000
# SMTP                  0.000000
# SSH                   0.000000
# IRC                   0.000000
# TCP                   1.000000
# UDP                   0.000000
# DHCP                  0.000000
# ARP                   0.000000
# ICMP                  0.000000
# IPv                   1.000000
# LLC                   1.000000
# Tot sum             459.000000
# Min                  54.000000
# Max                 192.400000
# AVG                  80.608889
# Std                  48.512534
# Tot size             76.400000
# IAT                   0.001282
# Number                5.500000
# Magnitue             12.632666
# Radius               68.607084
# Covariance         3168.703210
# Variance              0.900000
# Weight               38.500000
# label                27.000000
# Name: 133330, dtype: float64
# First instance of Recon-PingSweep (code 28):
# flow_duration         22.490828
# Header_Length      29325.000000
# Protocol Type          8.200000
# Duration             104.000000
# Rate                  17.819675
# Srate                 17.819675
# Drate                  0.000000
# fin_flag_number        0.000000
# syn_flag_number        0.000000
# rst_flag_number        0.000000
# psh_flag_number        0.000000
# ack_flag_number        1.000000
# ece_flag_number        0.000000
# cwr_flag_number        0.000000
# ack_count              0.600000
# syn_count              0.800000
# fin_count              0.000000
# urg_count             94.500000
# rst_count            195.500000
# HTTP                   0.000000
# HTTPS                  1.000000
# DNS                    0.000000
# Telnet                 0.000000
# SMTP                   0.000000
# SSH                    0.000000
# IRC                    0.000000
# TCP                    1.000000
# UDP                    0.000000
# DHCP                   0.000000
# ARP                    0.000000
# ICMP                   0.000000
# IPv                    1.000000
# LLC                    1.000000
# Tot sum              504.300000
# Min                   69.100000
# Max                  138.300000
# AVG                   90.607262
# Std                   26.734544
# Tot size              93.400000
# IAT                    0.022455
# Number                 5.500000
# Magnitue              13.452221
# Radius                37.808355
# Covariance           852.588342
# Variance               0.900000
# Weight                38.500000
# label                 28.000000
# Name: 46475, dtype: float64
# First instance of Recon-PortScan (code 29):
# flow_duration      1.040205e+00
# Header_Length      5.104700e+04
# Protocol Type      6.000000e+00
# Duration           5.140000e+01
# Rate               4.758206e+01
# Srate              4.758206e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          2.000000e+00
# fin_count          0.000000e+00
# urg_count          8.000000e+00
# rst_count          4.850000e+01
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            3.219000e+03
# Min                6.600000e+01
# Max                1.922400e+03
# AVG                3.750033e+02
# Std                6.227168e+02
# Tot size           1.351200e+03
# IAT                4.827976e-04
# Number             5.500000e+00
# Magnitue           2.187713e+01
# Radius             8.806545e+02
# Covariance         1.358510e+06
# Variance           3.000000e-01
# Weight             3.850000e+01
# label              2.900000e+01
# Name: 95923, dtype: float64
# First instance of SqlInjection (code 30):
# flow_duration        137.100136
# Header_Length      23990.300000
# Protocol Type          7.100000
# Duration              64.000000
# Rate                  42.848746
# Srate                 42.848746
# Drate                  0.000000
# fin_flag_number        0.000000
# syn_flag_number        0.000000
# rst_flag_number        0.000000
# psh_flag_number        0.000000
# ack_flag_number        1.000000
# ece_flag_number        0.000000
# cwr_flag_number        0.000000
# ack_count              0.500000
# syn_count              1.100000
# fin_count              0.000000
# urg_count            105.600000
# rst_count            212.300000
# HTTP                   0.000000
# HTTPS                  1.000000
# DNS                    0.000000
# Telnet                 0.000000
# SMTP                   0.000000
# SSH                    0.000000
# IRC                    0.000000
# TCP                    1.000000
# UDP                    0.000000
# DHCP                   0.000000
# ARP                    0.000000
# ICMP                   0.000000
# IPv                    1.000000
# LLC                    1.000000
# Tot sum              870.400000
# Min                  103.500000
# Max                  441.000000
# AVG                  193.910357
# Std                  129.511741
# Tot size             141.200000
# IAT                    0.015548
# Number                 5.500000
# Magnitue              19.299354
# Radius               183.157261
# Covariance         19071.406915
# Variance               0.900000
# Weight                38.500000
# label                 30.000000
# Name: 185074, dtype: float64
# First instance of Uploading_Attack (code 31):
# flow_duration           1.154966
# Header_Length      110660.200000
# Protocol Type           6.000000
# Duration               56.000000
# Rate                   77.477245
# Srate                  77.477245
# Drate                   0.000000
# fin_flag_number         0.000000
# syn_flag_number         0.000000
# rst_flag_number         0.000000
# psh_flag_number         0.000000
# ack_flag_number         1.000000
# ece_flag_number         0.000000
# cwr_flag_number         0.000000
# ack_count               0.000000
# syn_count               2.000000
# fin_count               0.000000
# urg_count               8.000000
# rst_count              88.500000
# HTTP                    0.000000
# HTTPS                   1.000000
# DNS                     0.000000
# Telnet                  0.000000
# SMTP                    0.000000
# SSH                     0.000000
# IRC                     0.000000
# TCP                     1.000000
# UDP                     0.000000
# DHCP                    0.000000
# ARP                     0.000000
# ICMP                    0.000000
# IPv                     1.000000
# LLC                     1.000000
# Tot sum              3076.200000
# Min                    66.000000
# Max                  1351.200000
# AVG                   387.413333
# Std                   450.744770
# Tot size              922.800000
# IAT                     0.002352
# Number                  5.500000
# Magnitue               24.284127
# Radius                637.449368
# Covariance         423872.318222
# Variance                0.500000
# Weight                 38.500000
# label                  31.000000
# Name: 448964, dtype: float64
# First instance of VulnerabilityScan (code 32):
# flow_duration      6.170458e+01
# Header_Length      8.775809e+05
# Protocol Type      9.020000e+00
# Duration           9.012000e+01
# Rate               2.718812e+01
# Srate              2.718812e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          1.400000e-01
# syn_count          4.600000e-01
# fin_count          0.000000e+00
# urg_count          6.125300e+02
# rst_count          1.246580e+03
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            3.378240e+03
# Min                7.625000e+01
# Max                1.048200e+03
# AVG                3.268365e+02
# Std                3.715075e+02
# Tot size           2.938700e+02
# IAT                8.324165e+07
# Number             9.500000e+00
# Magnitue           2.514568e+01
# Radius             5.259047e+02
# Covariance         1.550885e+05
# Variance           9.500000e-01
# Weight             1.415500e+02
# label              3.200000e+01
# Name: 121, dtype: float64
# First instance of XSS (code 33):
# flow_duration       1023.378933
# Header_Length      40977.600000
# Protocol Type          5.900000
# Duration             121.400000
# Rate                   0.766785
# Srate                  0.766785
# Drate                  0.000000
# fin_flag_number        0.000000
# syn_flag_number        0.000000
# rst_flag_number        0.000000
# psh_flag_number        0.000000
# ack_flag_number        1.000000
# ece_flag_number        0.000000
# cwr_flag_number        0.000000
# ack_count              0.000000
# syn_count              0.400000
# fin_count              0.000000
# urg_count            174.300000
# rst_count            340.700000
# HTTP                   0.000000
# HTTPS                  0.000000
# DNS                    0.000000
# Telnet                 0.000000
# SMTP                   0.000000
# SSH                    0.000000
# IRC                    0.000000
# TCP                    1.000000
# UDP                    0.000000
# DHCP                   0.000000
# ARP                    0.000000
# ICMP                   0.000000
# IPv                    1.000000
# LLC                    1.000000
# Tot sum              445.700000
# Min                   55.200000
# Max                  136.400000
# AVG                   76.994365
# Std                   26.983580
# Tot size              92.800000
# IAT                    0.053709
# Number                 5.500000
# Magnitue              12.380803
# Radius                38.160544
# Covariance          1001.527931
# Variance               0.900000
# Weight                38.500000
# label                 33.000000
# Name: 247148, dtype: float64

# %% [markdown]
# Save dataset for later comparison

# %%
original_data = full_data.copy()
original_data.head()
# Out:
#         flow_duration  Header_Length  Protocol Type  Duration         Rate  \
# 164260       0.147075       21224.00          17.00     64.00  4376.083823
# 159703       0.009695          69.94           6.22     63.62   133.539945
# 235836       0.220598       15592.63           1.45     64.00    59.932602
# 56911        0.000000          54.00           6.00     64.00     1.533302
# 141604       0.000000          54.00           6.00     64.00    65.774432
#
#               Srate  Drate  fin_flag_number  syn_flag_number  rst_flag_number  \
# 164260  4376.083823    0.0              0.0              0.0              0.0
# 159703   133.539945    0.0              0.0              1.0              0.0
# 235836    59.932602    0.0              0.0              0.0              0.0
# 56911      1.533302    0.0              0.0              0.0              0.0
# 141604    65.774432    0.0              0.0              1.0              0.0
#
#         ...         Std  Tot size           IAT  Number   Magnitue  \
# 164260  ...    0.000000     50.00  8.309876e+07     9.5  10.000000
# 159703  ...    2.328323     54.92  8.309331e+07     9.5  10.483598
# 235836  ...  145.840843    188.96  8.313249e+07     9.5  12.762688
# 56911   ...    0.000000     54.00  8.307238e+07     9.5  10.392305
# 141604  ...    0.000000     54.00  8.336248e+07     9.5  10.392305
#
#             Radius    Covariance  Variance  Weight  label
# 164260    0.000000      0.000000      0.00  141.55     14
# 159703    3.298447     26.885065      0.22  141.55     10
# 235836  206.388075  83210.101065      0.28  141.55      6
# 56911     0.000000      0.000000      0.00  141.55     13
# 141604    0.000000      0.000000      0.00  141.55     12
#
# [5 rows x 47 columns]

# %% [markdown]
# ## Scaling Numeric Features

# %%
# # feature scaling
# scaler = StandardScaler()
# 
# for data_set in tqdm(data_sets):
#     scaler.fit(pd.read_csv(DATASET_DIRECTORY + data_set)[num_cols])
#     
# # Scale the features in the dataframe
# full_data[num_cols] = scaler.transform(full_data[num_cols])
# 
# # Display the first few entries to verify the changes
# print(full_data)
# 
# # prep the data to be inputted into model
# data = full_data

# %% [markdown]
# ## Preprocessed DataFrame

# %%
full_data.head()
# Out:
#         flow_duration  Header_Length  Protocol Type  Duration         Rate  \
# 164260       0.147075       21224.00          17.00     64.00  4376.083823
# 159703       0.009695          69.94           6.22     63.62   133.539945
# 235836       0.220598       15592.63           1.45     64.00    59.932602
# 56911        0.000000          54.00           6.00     64.00     1.533302
# 141604       0.000000          54.00           6.00     64.00    65.774432
#
#               Srate  Drate  fin_flag_number  syn_flag_number  rst_flag_number  \
# 164260  4376.083823    0.0              0.0              0.0              0.0
# 159703   133.539945    0.0              0.0              1.0              0.0
# 235836    59.932602    0.0              0.0              0.0              0.0
# 56911      1.533302    0.0              0.0              0.0              0.0
# 141604    65.774432    0.0              0.0              1.0              0.0
#
#         ...         Std  Tot size           IAT  Number   Magnitue  \
# 164260  ...    0.000000     50.00  8.309876e+07     9.5  10.000000
# 159703  ...    2.328323     54.92  8.309331e+07     9.5  10.483598
# 235836  ...  145.840843    188.96  8.313249e+07     9.5  12.762688
# 56911   ...    0.000000     54.00  8.307238e+07     9.5  10.392305
# 141604  ...    0.000000     54.00  8.336248e+07     9.5  10.392305
#
#             Radius    Covariance  Variance  Weight  label
# 164260    0.000000      0.000000      0.00  141.55     14
# 159703    3.298447     26.885065      0.22  141.55     10
# 235836  206.388075  83210.101065      0.28  141.55      6
# 56911     0.000000      0.000000      0.00  141.55     13
# 141604    0.000000      0.000000      0.00  141.55     12
#
# [5 rows x 47 columns]

# %% [markdown]
# # Sampling (Condensed Nearest Neighbor Under-Sampling)

# %%
min_class_size = full_data['label'].value_counts().min()

# Apply random over-sampling
undersampler = CondensedNearestNeighbour()

X = full_data.drop('label', axis=1)
y = full_data['label']
X_resampled, y_res = undersampler.fit_resample(X, y)

# Combine the resampled features and labels back into a single DataFrame
full_data_resampled = pd.DataFrame(X_resampled, columns=X.columns)
full_data_resampled['label'] = y_res

print("Resampled Data (SCALED):")
for label, code in class_codes.items():
    # Print the first instance of each class
    print(f"First instance of {label} (code {code}):")
    print(full_data_resampled[full_data_resampled['label'] == code].iloc[0])

full_data_resampled.head()
# Out:
# Resampled Data (SCALED):
# First instance of Backdoor_Malware (code 0):
# flow_duration      9.758581e-01
# Header_Length      6.660940e+04
# Protocol Type      6.000000e+00
# Duration           5.040000e+01
# Rate               6.401756e+01
# Srate              6.401756e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          2.000000e+00
# fin_count          0.000000e+00
# urg_count          8.000000e+00
# rst_count          6.150000e+01
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            7.163400e+03
# Min                6.600000e+01
# Max                1.494000e+03
# AVG                4.697980e+02
# Std                6.396725e+02
# Tot size           3.516000e+02
# IAT                1.676297e+08
# Number             1.350000e+01
# Magnitue           3.041926e+01
# Radius             9.010165e+02
# Covariance         4.066875e+05
# Variance           1.000000e+00
# Weight             2.446000e+02
# label              0.000000e+00
# Name: 0, dtype: float64
# First instance of BenignTraffic (code 1):
# flow_duration      4.018265e+01
# Header_Length      3.115016e+06
# Protocol Type      7.100000e+00
# Duration           6.400000e+01
# Rate               6.618082e+01
# Srate              6.618082e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          9.630000e+01
# rst_count          2.925900e+03
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            1.774700e+04
# Min                6.600000e+01
# Max                1.514000e+03
# AVG                1.131463e+03
# Std                6.275893e+02
# Tot size           1.371600e+03
# IAT                1.665234e+08
# Number             1.350000e+01
# Magnitue           4.751393e+01
# Radius             8.890990e+02
# Covariance         3.965274e+05
# Variance           1.000000e+00
# Weight             2.446000e+02
# label              1.000000e+00
# Name: 42, dtype: float64
# First instance of BrowserHijacking (code 2):
# flow_duration      2.784080e+00
# Header_Length      1.271781e+06
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               3.918111e+02
# Srate              3.918111e+02
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          2.000000e+00
# fin_count          0.000000e+00
# urg_count          3.794000e+02
# rst_count          1.091300e+03
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.817400e+03
# Min                6.600000e+01
# Max                1.284500e+03
# AVG                3.429877e+02
# Std                4.628584e+02
# Tot size           1.079600e+03
# IAT                1.668458e+08
# Number             1.350000e+01
# Magnitue           2.505981e+01
# Radius             6.523696e+02
# Covariance         2.505487e+05
# Variance           1.000000e+00
# Weight             2.446000e+02
# label              2.000000e+00
# Name: 176, dtype: float64
# First instance of CommandInjection (code 3):
# flow_duration      1.027515e+01
# Header_Length      1.063934e+05
# Protocol Type      7.700000e+00
# Duration           5.070000e+01
# Rate               9.851878e+01
# Srate              9.851878e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          1.400000e+00
# fin_count          0.000000e+00
# urg_count          5.600000e+00
# rst_count          1.029000e+02
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            1.303190e+04
# Min                5.520000e+01
# Max                2.922000e+03
# AVG                8.609132e+02
# Std                8.361809e+02
# Tot size           2.547000e+02
# IAT                1.676386e+08
# Number             1.350000e+01
# Magnitue           4.149500e+01
# Radius             1.183636e+03
# Covariance         7.010084e+05
# Variance           1.000000e+00
# Weight             2.446000e+02
# label              3.000000e+00
# Name: 213, dtype: float64
# First instance of DDoS-ACK_Fragmentation (code 4):
# flow_duration      1.176934e-02
# Header_Length      3.120000e+02
# Protocol Type      7.420000e+00
# Duration           6.272000e+01
# Rate               5.246434e+04
# Srate              5.246434e+04
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    1.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          3.600000e-01
# fin_count          9.400000e-01
# urg_count          0.000000e+00
# rst_count          4.100000e-01
# HTTP               1.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            1.551620e+03
# Min                7.180000e+01
# Max                3.475000e+02
# AVG                1.612695e+02
# Std                1.158418e+02
# Tot size           1.436800e+02
# IAT                8.334011e+07
# Number             9.500000e+00
# Magnitue           1.512864e+01
# Radius             1.640359e+02
# Covariance         7.024103e+04
# Variance           5.200000e-01
# Weight             1.415500e+02
# label              4.000000e+00
# Name: 268, dtype: float64
# First instance of DDoS-HTTP_Flood (code 5):
# flow_duration      6.409796e+00
# Header_Length      5.765320e+03
# Protocol Type      6.270000e+00
# Duration           6.668000e+01
# Rate               2.501798e+00
# Srate              2.501798e+00
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          1.400000e-01
# syn_count          3.830000e+00
# fin_count          1.060000e+00
# urg_count          2.830000e+00
# rst_count          9.010000e+00
# HTTP               1.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            1.384140e+03
# Min                6.012000e+01
# Max                5.223900e+02
# AVG                1.271708e+02
# Std                1.337550e+02
# Tot size           1.542700e+02
# IAT                8.315817e+07
# Number             9.500000e+00
# Magnitue           1.549468e+01
# Radius             1.863475e+02
# Covariance         3.193744e+04
# Variance           9.300000e-01
# Weight             1.415500e+02
# label              5.000000e+00
# Name: 272, dtype: float64
# First instance of DDoS-ICMP_Flood (code 6):
# flow_duration      0.000000e+00
# Header_Length      0.000000e+00
# Protocol Type      1.000000e+00
# Duration           6.400000e+01
# Rate               1.260753e+02
# Srate              1.260753e+02
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               1.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            4.410000e+02
# Min                4.200000e+01
# Max                4.200000e+01
# AVG                4.200000e+01
# Std                0.000000e+00
# Tot size           4.200000e+01
# IAT                8.315027e+07
# Number             9.500000e+00
# Magnitue           9.165151e+00
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              6.000000e+00
# Name: 273, dtype: float64
# First instance of DDoS-ICMP_Fragmentation (code 7):
# flow_duration      3.139801e-03
# Header_Length      8.450000e+00
# Protocol Type      1.040000e+00
# Duration           6.321000e+01
# Rate               2.046418e+01
# Srate              2.046418e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          2.000000e-02
# syn_count          1.000000e-02
# fin_count          0.000000e+00
# urg_count          1.000000e-02
# rst_count          7.000000e-02
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               1.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            9.559660e+03
# Min                3.405800e+02
# Max                1.479440e+03
# AVG                9.059528e+02
# Std                5.458104e+02
# Tot size           9.089800e+02
# IAT                8.325338e+07
# Number             9.500000e+00
# Magnitue           4.240848e+01
# Radius             7.717141e+02
# Covariance         3.135317e+05
# Variance           9.500000e-01
# Weight             1.415500e+02
# label              7.000000e+00
# Name: 276, dtype: float64
# First instance of DDoS-PSHACK_Flood (code 8):
# flow_duration      0.000000e+00
# Header_Length      5.346000e+01
# Protocol Type      5.940000e+00
# Duration           6.336000e+01
# Rate               5.606362e-01
# Srate              5.606362e-01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    1.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          9.900000e-01
# rst_count          9.900000e-01
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.675400e+02
# Min                5.400000e+01
# Max                5.454000e+01
# AVG                5.403467e+01
# Std                1.318498e-01
# Tot size           5.406000e+01
# IAT                8.333203e+07
# Number             9.500000e+00
# Magnitue           1.039565e+01
# Radius             1.869179e-01
# Covariance         1.951534e-01
# Variance           9.000000e-02
# Weight             1.415500e+02
# label              8.000000e+00
# Name: 280, dtype: float64
# First instance of DDoS-RSTFINFlood (code 9):
# flow_duration      0.000000e+00
# Header_Length      5.400000e+01
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               1.197110e+01
# Srate              1.197110e+01
# Drate              0.000000e+00
# fin_flag_number    1.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    1.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          1.000000e+00
# syn_count          0.000000e+00
# fin_count          1.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.670000e+02
# Min                5.400000e+01
# Max                5.400000e+01
# AVG                5.400000e+01
# Std                0.000000e+00
# Tot size           5.400000e+01
# IAT                8.334093e+07
# Number             9.500000e+00
# Magnitue           1.039230e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              9.000000e+00
# Name: 282, dtype: float64
# First instance of DDoS-SYN_Flood (code 10):
# flow_duration      0.000000e+00
# Header_Length      5.400000e+01
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               2.208046e+01
# Srate              2.208046e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    1.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          1.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.670000e+02
# Min                5.400000e+01
# Max                5.400000e+01
# AVG                5.400000e+01
# Std                0.000000e+00
# Tot size           5.400000e+01
# IAT                8.309339e+07
# Number             9.500000e+00
# Magnitue           1.039230e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              1.000000e+01
# Name: 285, dtype: float64
# First instance of DDoS-SlowLoris (code 11):
# flow_duration      1.970899e-01
# Header_Length      1.898400e+02
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               7.938950e+01
# Srate              7.938950e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          4.000000e-02
# syn_count          1.800000e-01
# fin_count          4.000000e-02
# urg_count          1.020000e+00
# rst_count          2.120000e+00
# HTTP               1.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            7.188800e+02
# Min                6.360000e+01
# Max                8.781000e+01
# AVG                6.735111e+01
# Std                6.926244e+00
# Tot size           6.991000e+01
# IAT                8.337538e+07
# Number             9.500000e+00
# Magnitue           1.159592e+01
# Radius             9.814833e+00
# Covariance         2.666493e+02
# Variance           2.900000e-01
# Weight             1.415500e+02
# label              1.100000e+01
# Name: 289, dtype: float64
# First instance of DDoS-SynonymousIP_Flood (code 12):
# flow_duration      2.674066e+00
# Header_Length      1.080000e+02
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               7.494850e-01
# Srate              7.494850e-01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    1.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          2.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.670000e+02
# Min                5.400000e+01
# Max                5.400000e+01
# AVG                5.400000e+01
# Std                0.000000e+00
# Tot size           5.400000e+01
# IAT                8.336192e+07
# Number             9.500000e+00
# Magnitue           1.039230e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              1.200000e+01
# Name: 290, dtype: float64
# First instance of DDoS-TCP_Flood (code 13):
# flow_duration      0.000000e+00
# Header_Length      5.400000e+01
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               2.539813e+01
# Srate              2.539813e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.670000e+02
# Min                5.400000e+01
# Max                5.400000e+01
# AVG                5.400000e+01
# Std                0.000000e+00
# Tot size           5.400000e+01
# IAT                8.303338e+07
# Number             9.500000e+00
# Magnitue           1.039230e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              1.300000e+01
# Name: 295, dtype: float64
# First instance of DDoS-UDP_Flood (code 14):
# flow_duration      9.168106e-02
# Header_Length      4.060750e+04
# Protocol Type      1.700000e+01
# Duration           6.400000e+01
# Rate               8.785328e+03
# Srate              8.785328e+03
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                1.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.250000e+02
# Min                5.000000e+01
# Max                5.000000e+01
# AVG                5.000000e+01
# Std                0.000000e+00
# Tot size           5.000000e+01
# IAT                8.310661e+07
# Number             9.500000e+00
# Magnitue           1.000000e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              1.400000e+01
# Name: 298, dtype: float64
# First instance of DDoS-UDP_Fragmentation (code 15):
# flow_duration      4.941034e-01
# Header_Length      3.364865e+05
# Protocol Type      1.700000e+01
# Duration           6.400000e+01
# Rate               4.493477e+02
# Srate              4.493477e+02
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            9.561000e+03
# Min                3.620000e+02
# Max                1.456400e+03
# AVG                8.765622e+02
# Std                5.441389e+02
# Tot size           9.380000e+02
# IAT                8.336641e+07
# Number             9.500000e+00
# Magnitue           4.168060e+01
# Radius             7.694721e+02
# Covariance         3.116788e+05
# Variance           9.500000e-01
# Weight             1.415500e+02
# label              1.500000e+01
# Name: 304, dtype: float64
# First instance of DNS_Spoofing (code 16):
# flow_duration        0.000000
# Header_Length        0.000000
# Protocol Type        1.000000
# Duration            64.000000
# Rate               133.309062
# Srate              133.309062
# Drate                0.000000
# fin_flag_number      0.000000
# syn_flag_number      0.000000
# rst_flag_number      0.000000
# psh_flag_number      0.000000
# ack_flag_number      0.000000
# ece_flag_number      0.000000
# cwr_flag_number      0.000000
# ack_count            0.000000
# syn_count            0.000000
# fin_count            0.000000
# urg_count            0.000000
# rst_count            0.000000
# HTTP                 0.000000
# HTTPS                0.000000
# DNS                  0.000000
# Telnet               0.000000
# SMTP                 0.000000
# SSH                  0.000000
# IRC                  0.000000
# TCP                  0.000000
# UDP                  0.000000
# DHCP                 0.000000
# ARP                  0.000000
# ICMP                 1.000000
# IPv                  1.000000
# LLC                  1.000000
# Tot sum            385.000000
# Min                 70.000000
# Max                 70.000000
# AVG                 70.000000
# Std                  0.000000
# Tot size            70.000000
# IAT                  0.000055
# Number               5.500000
# Magnitue            11.832160
# Radius               0.000000
# Covariance           0.000000
# Variance             0.000000
# Weight              38.500000
# label               16.000000
# Name: 308, dtype: float64
# First instance of DictionaryBruteForce (code 17):
# flow_duration           0.914982
# Header_Length       76956.000000
# Protocol Type           5.400000
# Duration               51.200000
# Rate                   84.415037
# Srate                  84.415037
# Drate                   0.000000
# fin_flag_number         0.000000
# syn_flag_number         0.000000
# rst_flag_number         0.000000
# psh_flag_number         0.000000
# ack_flag_number         1.000000
# ece_flag_number         0.000000
# cwr_flag_number         0.000000
# ack_count               0.000000
# syn_count               1.800000
# fin_count               0.000000
# urg_count               7.200000
# rst_count              76.500000
# HTTP                    0.000000
# HTTPS                   1.000000
# DNS                     0.000000
# Telnet                  0.000000
# SMTP                    0.000000
# SSH                     0.000000
# IRC                     0.000000
# TCP                     1.000000
# UDP                     0.000000
# DHCP                    0.000000
# ARP                     0.000000
# ICMP                    0.000000
# IPv                     1.000000
# LLC                     1.000000
# Tot sum              3642.600000
# Min                    61.200000
# Max                  1351.200000
# AVG                   592.029286
# Std                   622.918450
# Tot size              779.400000
# IAT                     0.004782
# Number                  5.500000
# Magnitue               33.461933
# Radius                880.939720
# Covariance         431949.907852
# Variance                0.900000
# Weight                 38.500000
# label                  17.000000
# Name: 420, dtype: float64
# First instance of DoS-HTTP_Flood (code 18):
# flow_duration      5.565228e+00
# Header_Length      1.280553e+04
# Protocol Type      6.110000e+00
# Duration           6.586000e+01
# Rate               2.479959e+00
# Srate              2.479959e+00
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          2.100000e-01
# syn_count          6.000000e-01
# fin_count          1.470000e+00
# urg_count          3.740000e+00
# rst_count          1.211000e+01
# HTTP               1.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            7.274380e+03
# Min                8.344000e+01
# Max                2.280600e+03
# AVG                6.107397e+02
# Std                7.776174e+02
# Tot size           7.892400e+02
# IAT                8.300268e+07
# Number             9.500000e+00
# Magnitue           3.244025e+01
# Radius             1.100716e+03
# Covariance         7.985207e+05
# Variance           8.500000e-01
# Weight             1.415500e+02
# label              1.800000e+01
# Name: 474, dtype: float64
# First instance of DoS-SYN_Flood (code 19):
# flow_duration      4.453824e-01
# Header_Length      1.665800e+02
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               6.808758e+00
# Srate              6.808758e+00
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    1.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          2.000000e+00
# fin_count          1.010000e+00
# urg_count          0.000000e+00
# rst_count          1.010000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.670000e+02
# Min                5.400000e+01
# Max                5.400000e+01
# AVG                5.400000e+01
# Std                0.000000e+00
# Tot size           5.400000e+01
# IAT                8.297239e+07
# Number             9.500000e+00
# Magnitue           1.039230e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              1.900000e+01
# Name: 477, dtype: float64
# First instance of DoS-TCP_Flood (code 20):
# flow_duration      0.000000e+00
# Header_Length      5.400000e+01
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               2.395869e+01
# Srate              2.395869e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.670000e+02
# Min                5.400000e+01
# Max                5.400000e+01
# AVG                5.400000e+01
# Std                0.000000e+00
# Tot size           5.400000e+01
# IAT                8.295610e+07
# Number             9.500000e+00
# Magnitue           1.039230e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              2.000000e+01
# Name: 480, dtype: float64
# First instance of DoS-UDP_Flood (code 21):
# flow_duration      8.007809e-02
# Header_Length      2.301900e+04
# Protocol Type      1.700000e+01
# Duration           6.400000e+01
# Rate               6.037296e+03
# Srate              6.037296e+03
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                1.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.250000e+02
# Min                5.000000e+01
# Max                5.000000e+01
# AVG                5.000000e+01
# Std                0.000000e+00
# Tot size           5.000000e+01
# IAT                8.301589e+07
# Number             9.500000e+00
# Magnitue           1.000000e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             1.415500e+02
# label              2.100000e+01
# Name: 484, dtype: float64
# First instance of MITM-ArpSpoofing (code 22):
# flow_duration      8.802712e+00
# Header_Length      7.234703e+06
# Protocol Type      6.000000e+00
# Duration           6.400000e+01
# Rate               7.661843e+02
# Srate              7.661843e+02
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          2.199000e+03
# rst_count          6.744500e+03
# HTTP               0.000000e+00
# HTTPS              1.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            4.290000e+02
# Min                7.800000e+01
# Max                7.800000e+01
# AVG                7.800000e+01
# Std                0.000000e+00
# Tot size           7.800000e+01
# IAT                3.385544e-06
# Number             5.500000e+00
# Magnitue           1.249000e+01
# Radius             0.000000e+00
# Covariance         0.000000e+00
# Variance           0.000000e+00
# Weight             3.850000e+01
# label              2.200000e+01
# Name: 487, dtype: float64
# First instance of Mirai-greeth_flood (code 23):
# flow_duration      2.390440e-03
# Header_Length      2.010000e+00
# Protocol Type      4.659000e+01
# Duration           6.567000e+01
# Rate               5.908529e+00
# Srate              5.908529e+00
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          2.000000e-02
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          1.000000e-02
# rst_count          2.000000e-02
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            6.161160e+03
# Min                5.371600e+02
# Max                5.920000e+02
# AVG                5.879789e+02
# Std                1.416356e+01
# Tot size           5.874300e+02
# IAT                8.368129e+07
# Number             9.500000e+00
# Magnitue           3.429026e+01
# Radius             2.006488e+01
# Covariance         1.698993e+03
# Variance           1.200000e-01
# Weight             1.415500e+02
# label              2.300000e+01
# Name: 596, dtype: float64
# First instance of Mirai-greip_flood (code 24):
# flow_duration      0.000000e+00
# Header_Length      5.010000e+00
# Protocol Type      4.599000e+01
# Duration           6.591000e+01
# Rate               2.322961e+01
# Srate              2.322961e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          1.000000e-02
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.921130e+03
# Min                5.126600e+02
# Max                5.780000e+02
# AVG                5.670923e+02
# Std                2.254598e+01
# Tot size           5.656700e+02
# IAT                8.366388e+07
# Number             9.500000e+00
# Magnitue           3.366485e+01
# Radius             3.193220e+01
# Covariance         3.946002e+03
# Variance           1.300000e-01
# Weight             1.415500e+02
# label              2.400000e+01
# Name: 600, dtype: float64
# First instance of Mirai-udpplain (code 25):
# flow_duration      1.311483e+00
# Header_Length      1.332752e+06
# Protocol Type      1.683000e+01
# Duration           6.336000e+01
# Rate               1.776854e+03
# Srate              1.776854e+03
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    0.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          0.000000e+00
# fin_count          0.000000e+00
# urg_count          0.000000e+00
# rst_count          0.000000e+00
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                0.000000e+00
# UDP                1.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            5.797240e+03
# Min                5.342400e+02
# Max                5.540000e+02
# AVG                5.529280e+02
# Std                4.473651e+00
# Tot size           5.490600e+02
# IAT                8.378471e+07
# Number             9.500000e+00
# Magnitue           3.325363e+01
# Radius             6.364088e+00
# Covariance         5.065100e+02
# Variance           4.000000e-02
# Weight             1.415500e+02
# label              2.500000e+01
# Name: 606, dtype: float64
# First instance of Recon-HostDiscovery (code 26):
# flow_duration      4.443693e-03
# Header_Length      6.100000e+01
# Protocol Type      6.000000e+00
# Duration           7.470000e+01
# Rate               4.500761e+01
# Srate              4.500761e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    1.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          0.000000e+00
# syn_count          4.000000e-01
# fin_count          7.000000e-01
# urg_count          0.000000e+00
# rst_count          7.000000e-01
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            8.758000e+02
# Min                5.400000e+01
# Max                5.800000e+01
# AVG                5.655826e+01
# Std                1.893221e+00
# Tot size           5.560000e+01
# IAT                1.668466e+08
# Number             1.350000e+01
# Magnitue           1.063469e+01
# Radius             2.678444e+00
# Covariance         3.595659e+00
# Variance           1.000000e+00
# Weight             2.446000e+02
# label              2.600000e+01
# Name: 608, dtype: float64
# First instance of Recon-OSScan (code 27):
# flow_duration      7.521038e+01
# Header_Length      7.728600e+03
# Protocol Type      6.000000e+00
# Duration           7.640000e+01
# Rate               4.434067e+00
# Srate              4.434067e+00
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          1.000000e-01
# syn_count          4.000000e-01
# fin_count          0.000000e+00
# urg_count          3.360000e+01
# rst_count          6.810000e+01
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            1.694200e+03
# Min                5.000000e+01
# Max                4.714000e+02
# AVG                1.066894e+02
# Std                1.020919e+02
# Tot size           1.541000e+02
# IAT                1.664307e+08
# Number             1.350000e+01
# Magnitue           1.455492e+01
# Radius             1.449035e+02
# Covariance         1.213487e+04
# Variance           1.000000e+00
# Weight             2.446000e+02
# label              2.700000e+01
# Name: 720, dtype: float64
# First instance of Recon-PingSweep (code 28):
# flow_duration      1.445455e+01
# Header_Length      7.131500e+03
# Protocol Type      6.000000e+00
# Duration           5.680000e+01
# Rate               1.183728e+01
# Srate              1.183728e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          3.000000e-01
# syn_count          5.000000e-01
# fin_count          0.000000e+00
# urg_count          3.220000e+01
# rst_count          6.450000e+01
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            1.778100e+03
# Min                6.180000e+01
# Max                4.410000e+02
# AVG                1.161795e+02
# Std                1.001199e+02
# Tot size           8.100000e+01
# IAT                1.664480e+08
# Number             1.350000e+01
# Magnitue           1.521699e+01
# Radius             1.418244e+02
# Covariance         1.011010e+04
# Variance           1.000000e+00
# Weight             2.446000e+02
# label              2.800000e+01
# Name: 816, dtype: float64
# First instance of Recon-PortScan (code 29):
# flow_duration        39.797221
# Header_Length      9467.600000
# Protocol Type         8.700000
# Duration             75.000000
# Rate                 35.478275
# Srate                35.478275
# Drate                 0.000000
# fin_flag_number       0.000000
# syn_flag_number       0.000000
# rst_flag_number       0.000000
# psh_flag_number       0.000000
# ack_flag_number       0.000000
# ece_flag_number       0.000000
# cwr_flag_number       0.000000
# ack_count             0.200000
# syn_count             1.000000
# fin_count             0.000000
# urg_count            41.300000
# rst_count            82.800000
# HTTP                  0.000000
# HTTPS                 0.000000
# DNS                   0.000000
# Telnet                0.000000
# SMTP                  0.000000
# SSH                   0.000000
# IRC                   0.000000
# TCP                   1.000000
# UDP                   0.000000
# DHCP                  0.000000
# ARP                   0.000000
# ICMP                  0.000000
# IPv                   1.000000
# LLC                   1.000000
# Tot sum             469.500000
# Min                  67.000000
# Max                 126.800000
# AVG                  83.182540
# Std                  19.276993
# Tot size             83.800000
# IAT                   0.014155
# Number                5.500000
# Magnitue             12.889053
# Radius               27.261784
# Covariance          509.146703
# Variance              0.900000
# Weight               38.500000
# label                29.000000
# Name: 839, dtype: float64
# First instance of SqlInjection (code 30):
# flow_duration        290.749091
# Header_Length       5504.100000
# Protocol Type          7.100000
# Duration             135.300000
# Rate                  57.816940
# Srate                 57.816940
# Drate                  0.000000
# fin_flag_number        0.000000
# syn_flag_number        0.000000
# rst_flag_number        0.000000
# psh_flag_number        0.000000
# ack_flag_number        1.000000
# ece_flag_number        0.000000
# cwr_flag_number        0.000000
# ack_count              0.000000
# syn_count              1.900000
# fin_count              0.100000
# urg_count              4.300000
# rst_count              9.300000
# HTTP                   0.000000
# HTTPS                  1.000000
# DNS                    0.000000
# Telnet                 0.000000
# SMTP                   0.000000
# SSH                    0.000000
# IRC                    0.000000
# TCP                    1.000000
# UDP                    0.000000
# DHCP                   0.000000
# ARP                    0.000000
# ICMP                   0.000000
# IPv                    1.000000
# LLC                    1.000000
# Tot sum              885.300000
# Min                  115.200000
# Max                  394.000000
# AVG                  198.861627
# Std                  105.061138
# Tot size             133.000000
# IAT                    0.010389
# Number                 5.500000
# Magnitue              19.567906
# Radius               148.578886
# Covariance         12510.261823
# Variance               0.900000
# Weight                38.500000
# label                 30.000000
# Name: 937, dtype: float64
# First instance of Uploading_Attack (code 31):
# flow_duration           1.154966
# Header_Length      110660.200000
# Protocol Type           6.000000
# Duration               56.000000
# Rate                   77.477245
# Srate                  77.477245
# Drate                   0.000000
# fin_flag_number         0.000000
# syn_flag_number         0.000000
# rst_flag_number         0.000000
# psh_flag_number         0.000000
# ack_flag_number         1.000000
# ece_flag_number         0.000000
# cwr_flag_number         0.000000
# ack_count               0.000000
# syn_count               2.000000
# fin_count               0.000000
# urg_count               8.000000
# rst_count              88.500000
# HTTP                    0.000000
# HTTPS                   1.000000
# DNS                     0.000000
# Telnet                  0.000000
# SMTP                    0.000000
# SSH                     0.000000
# IRC                     0.000000
# TCP                     1.000000
# UDP                     0.000000
# DHCP                    0.000000
# ARP                     0.000000
# ICMP                    0.000000
# IPv                     1.000000
# LLC                     1.000000
# Tot sum              3076.200000
# Min                    66.000000
# Max                  1351.200000
# AVG                   387.413333
# Std                   450.744770
# Tot size              922.800000
# IAT                     0.002352
# Number                  5.500000
# Magnitue               24.284127
# Radius                637.449368
# Covariance         423872.318222
# Variance                0.500000
# Weight                 38.500000
# label                  31.000000
# Name: 967, dtype: float64
# First instance of VulnerabilityScan (code 32):
# flow_duration      3.414130e+01
# Header_Length      1.885820e+03
# Protocol Type      9.020000e+00
# Duration           9.673000e+01
# Rate               3.108956e+01
# Srate              3.108956e+01
# Drate              0.000000e+00
# fin_flag_number    0.000000e+00
# syn_flag_number    0.000000e+00
# rst_flag_number    0.000000e+00
# psh_flag_number    0.000000e+00
# ack_flag_number    1.000000e+00
# ece_flag_number    0.000000e+00
# cwr_flag_number    0.000000e+00
# ack_count          3.200000e-01
# syn_count          9.100000e-01
# fin_count          0.000000e+00
# urg_count          5.970000e+00
# rst_count          1.226000e+01
# HTTP               0.000000e+00
# HTTPS              0.000000e+00
# DNS                0.000000e+00
# Telnet             0.000000e+00
# SMTP               0.000000e+00
# SSH                0.000000e+00
# IRC                0.000000e+00
# TCP                1.000000e+00
# UDP                0.000000e+00
# DHCP               0.000000e+00
# ARP                0.000000e+00
# ICMP               0.000000e+00
# IPv                1.000000e+00
# LLC                1.000000e+00
# Tot sum            1.143150e+03
# Min                5.982000e+01
# Max                2.412900e+02
# AVG                1.039357e+02
# Std                5.666328e+01
# Tot size           1.077900e+02
# IAT                8.324387e+07
# Number             9.500000e+00
# Magnitue           1.429976e+01
# Radius             8.023660e+01
# Covariance         4.035664e+03
# Variance           9.400000e-01
# Weight             1.415500e+02
# label              3.200000e+01
# Name: 1007, dtype: float64
# First instance of XSS (code 33):
# flow_duration        124.272426
# Header_Length       2426.800000
# Protocol Type          9.300000
# Duration             124.500000
# Rate                  61.117632
# Srate                 61.117632
# Drate                  0.000000
# fin_flag_number        0.000000
# syn_flag_number        0.000000
# rst_flag_number        0.000000
# psh_flag_number        0.000000
# ack_flag_number        1.000000
# ece_flag_number        0.000000
# cwr_flag_number        0.000000
# ack_count              0.000000
# syn_count              1.400000
# fin_count              0.000000
# urg_count              1.200000
# rst_count              3.500000
# HTTP                   0.000000
# HTTPS                  1.000000
# DNS                    0.000000
# Telnet                 0.000000
# SMTP                   0.000000
# SSH                    0.000000
# IRC                    0.000000
# TCP                    1.000000
# UDP                    0.000000
# DHCP                   0.000000
# ARP                    0.000000
# ICMP                   0.000000
# IPv                    1.000000
# LLC                    1.000000
# Tot sum             1092.300000
# Min                   66.000000
# Max                  531.300000
# AVG                  202.817778
# Std                  173.095050
# Tot size             180.200000
# IAT                    0.009104
# Number                 5.500000
# Magnitue              19.853165
# Radius               244.793368
# Covariance         34452.972604
# Variance               0.900000
# Weight                38.500000
# label                 33.000000
# Name: 1008, dtype: float64
#    flow_duration  Header_Length  Protocol Type  Duration        Rate  \
# 0       0.975858        66609.4            6.0      50.4   64.017555
# 1     197.271666        11705.3            6.0     104.7   75.845424
# 2    1760.627373        15276.2           12.6      74.6    0.062983
# 3      55.706056         6109.2           14.3     108.7  394.899773
# 4     269.472210        13603.0            7.1      82.7  164.231782
#
#         Srate  Drate  fin_flag_number  syn_flag_number  rst_flag_number  ...  \
# 0   64.017555    0.0              0.0              0.0              0.0  ...
# 1   75.845424    0.0              0.0              0.0              0.0  ...
# 2    0.062983    0.0              0.0              0.0              0.0  ...
# 3  394.899773    0.0              0.0              0.0              0.0  ...
# 4  164.231782    0.0              0.0              0.0              0.0  ...
#
#           Std  Tot size           IAT  Number   Magnitue      Radius  \
# 0  639.672476     351.6  1.676297e+08    13.5  30.419257  901.016534
# 1  588.228870     147.4  1.676299e+08    13.5  30.581277  833.158486
# 2  121.749366     185.9  1.903262e-02     5.5  20.647813  172.179605
# 3   62.412485     171.4  1.676297e+08    13.5  15.384394   87.961674
# 4   73.950560     104.3  4.173017e-03     5.5  15.885492  104.581885
#
#       Covariance  Variance  Weight  label
# 0  406687.527512       1.0   244.6      0
# 1  348274.713591       1.0   244.6      0
# 2   16481.338452       0.9    38.5      0
# 3    3873.426256       1.0   244.6      0
# 4    6233.014506       0.9    38.5      0
#
# [5 rows x 47 columns]

# %% [markdown]
# # Post-Processing
# ## Inverse-Scaling

# %%
# full_data_resampled[num_cols] = scaler.inverse_transform(full_data_resampled[num_cols], copy=None)
# 
# print("Resampled Data (UNSCALED):")
# for label, code in class_codes.items():
#     # Print the first instance of each class
#     print(f"First instance of {label} (code {code}):")
#     print(full_data_resampled[full_data_resampled['label'] == code].iloc[0])
# 
# print("Number of negative values in DataFrame: ")
# print(sum(n < 0 for n in full_data_resampled.values.flatten()))
# 
# full_data_resampled.head()

# %% [markdown]
# ## Synthetic Data Analysis

# %%
full_data_resampled.describe()
# Out:
#        flow_duration  Header_Length  Protocol Type    Duration           Rate  \
# count    1069.000000   1.069000e+03    1069.000000  1069.00000    1069.000000
# mean      309.898999   8.493676e+04       8.809531    96.98473    2672.394060
# std      2426.498554   4.869422e+05       4.682025    40.08694   26039.362786
# min         0.000000   0.000000e+00       0.000000     0.00000       0.033641
# 25%         1.893714   2.485200e+03       6.000000    64.00000       5.562707
# 50%        24.183873   7.539500e+03       7.600000    87.10000      22.955122
# 75%       161.001550   2.223250e+04      10.400000   118.20000      76.476637
# max     51182.926771   9.233031e+06      47.000000   247.80000  524910.331235
#
#                Srate   Drate  fin_flag_number  syn_flag_number  \
# count    1069.000000  1069.0      1069.000000      1069.000000
# mean     2672.394060     0.0         0.003742         0.035547
# std     26039.362786     0.0         0.061084         0.185245
# min         0.033641     0.0         0.000000         0.000000
# 25%         5.562707     0.0         0.000000         0.000000
# 50%        22.955122     0.0         0.000000         0.000000
# 75%        76.476637     0.0         0.000000         0.000000
# max    524910.331235     0.0         1.000000         1.000000
#
#        rst_flag_number  ...          Std     Tot size           IAT  \
# count      1069.000000  ...  1069.000000  1069.000000  1.069000e+03
# mean          0.018709  ...   203.034880   333.785704  2.081977e+07
# std           0.135559  ...   356.521939   516.096902  5.407031e+07
# min           0.000000  ...     0.000000    42.000000  2.980232e-07
# 25%           0.000000  ...    22.545978    85.900000  3.767991e-03
# 50%           0.000000  ...    56.611538   121.500000  1.358440e-02
# 75%           0.000000  ...   149.163106   223.900000  3.138831e-02
# max           1.000000  ...  3206.440385  3704.000000  1.676394e+08
#
#             Number     Magnitue       Radius    Covariance     Variance  \
# count  1069.000000  1069.000000  1069.000000  1.069000e+03  1069.000000
# mean      6.480823    21.014848   287.069814  2.092984e+05     0.787617
# std       2.657555    13.970930   504.467301  7.289895e+05     0.267202
# min       1.000000     9.165151     0.000000  0.000000e+00     0.000000
# 25%       5.500000    12.820782    31.932203  8.087095e+02     0.800000
# 50%       5.500000    15.414805    79.975591  3.847493e+03     0.900000
# 75%       5.500000    21.017304   211.261154  3.430546e+04     0.900000
# max      13.500000    87.177081  4543.962586  1.232870e+07     1.000000
#
#             Weight        label
# count  1069.000000  1069.000000
# mean     64.407203    18.334892
# std      67.039701    11.195994
# min       1.000000     0.000000
# 25%      38.500000     3.000000
# 50%      38.500000    22.000000
# 75%      38.500000    27.000000
# max     244.600000    33.000000
#
# [8 rows x 47 columns]

# %%
from ydata_profiling import ProfileReport

original_report = ProfileReport(original_data, title='Original Data', minimal=True)
resampled_report = ProfileReport(full_data_resampled, title='Resampled Data', minimal=True)
comparison_report = original_report.compare(resampled_report)
comparison_report.to_file('./profile_reports/cnn_original_vs_resampled.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
